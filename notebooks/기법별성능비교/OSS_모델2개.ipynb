# %% [markdown]
# # One-Sided Selection + 모델 2개 성능 비교
#
# 이 notebook은 `docs/기법별_성능평가.md`의 평가 계획에 맞춰 `Undersampling OSS + 모델 2개` 실험을 준비하는 템플릿입니다.

# %% [markdown]
# ## 목적
#
# OneSidedSelection(OSS)으로 노이즈와 중복 다수 클래스 샘플을 줄였을 때 모델 1의 분류 성능 변화를 확인한다.
#
# OSS는 Tomek Links와 Condensed Nearest Neighbour 성격을 함께 활용하는 undersampling 기법이다. 전체 데이터에서는 오래 걸릴 수 있다.

# %% [markdown]
# ## 필요한 입력 파일
#
# - `data/processed/original_train_train_preprocessed.csv`
# - `data/processed/original_train_val_preprocessed.csv`
# - `data/processed/original_train_test_preprocessed.csv`
# - `artifacts/preprocessors/original_train_preprocess_config.json`
#
# ## 실행 절차
#
# 1. 입력 파일과 feature 목록을 확인한다.
# 2. 모델 1 학습용 train split에만 imbalanced-learn sampling을 적용한다.
# 3. sampling된 train CSV를 저장한다.
# 4. 모델 1은 sampling된 train CSV로 학습한다.
# 5. 모델 2는 sampling을 적용하지 않고, 기존 스크립트가 `위험도 > 0` 데이터만 필터링하여 학습한다.
# 6. 결과 지표를 계산하고 `docs/기법별_성능평가.md` 평가표에 옮겨 적는다.
#
# ## 모델 2 주의사항
#
# 모델 2 회귀모델은 항상 `위험도 > 0` 데이터만 사용한다. Sampling 기법은 모델 1의 `사고발생` 분류 문제에만 적용한다.

# %%
from __future__ import annotations

import json
import math
import subprocess
import sys
from pathlib import Path

import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.metrics import average_precision_score, mean_absolute_error, mean_squared_error

from imblearn.under_sampling import OneSidedSelection

PROJECT_ROOT = next(
    candidate for candidate in [Path.cwd(), *Path.cwd().parents]
    if (candidate / 'src').exists()
)

DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
TRAIN_PATH = DATA_DIR / 'original_train_train_preprocessed.csv'
VAL_PATH = DATA_DIR / 'original_train_val_preprocessed.csv'
TEST_PATH = DATA_DIR / 'original_train_test_preprocessed.csv'
PREPROCESS_CONFIG_PATH = PROJECT_ROOT / 'artifacts' / 'preprocessors' / 'original_train_preprocess_config.json'

EXPERIMENT_NAME = 'Undersampling OSS + 모델 2개'
EXPERIMENT_SLUG = 'one_sided_selection_two_stage'
RANDOM_STATE = 42
ROW_LIMIT = None  # None이면 전체 train 데이터를 사용한다.
RUN_SAMPLING = True  # 실제 sampling CSV를 만들려면 True로 변경한다.
RUN_TRAINING = True  # 실제 모델 학습까지 실행하려면 True로 변경한다.

OUTPUT_DIR = PROJECT_ROOT / 'artifacts' / 'experiments' / EXPERIMENT_SLUG
SAMPLED_INPUT_DIR = PROJECT_ROOT / 'artifacts' / 'experiments' / 'sampling_inputs'
SAMPLED_TRAIN_PATH = SAMPLED_INPUT_DIR / f'{EXPERIMENT_SLUG}_model1_train_preprocessed.csv'

MODEL1_MODEL_PATH = PROJECT_ROOT / 'artifacts' / 'models' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}.keras'
MODEL1_METRICS_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}_metrics.json'
MODEL1_HISTORY_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}_history.csv'
MODEL1_PREDICTIONS_PATH = PROJECT_ROOT / 'artifacts' / 'predictions' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}_test_predictions.csv'

MODEL2_MODEL_PATH = PROJECT_ROOT / 'artifacts' / 'models' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}.keras'
MODEL2_METRICS_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}_metrics.json'
MODEL2_HISTORY_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}_history.csv'
MODEL2_PREDICTIONS_PATH = PROJECT_ROOT / 'artifacts' / 'predictions' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}_test_predictions.csv'

EXPERIMENT_RESULT_PATH = OUTPUT_DIR / f'{EXPERIMENT_SLUG}_summary.csv'
DOCS_TABLE_PATH = PROJECT_ROOT / 'docs' / '기법별_성능평가.md'

# %%
required_paths = {
    'train': TRAIN_PATH,
    'val': VAL_PATH,
    'test': TEST_PATH,
    'preprocess_config': PREPROCESS_CONFIG_PATH,
    'docs_table': DOCS_TABLE_PATH,
}

path_status = pd.DataFrame(
    [{'name': name, 'path': str(path.relative_to(PROJECT_ROOT)), 'exists': path.exists()} for name, path in required_paths.items()]
)
display(path_status)

missing = path_status.loc[~path_status['exists'], 'path'].tolist()
if missing:
    raise FileNotFoundError(f'필요한 파일이 없습니다: {missing}')

with PREPROCESS_CONFIG_PATH.open('r', encoding='utf-8') as file:
    preprocess_config = json.load(file)

feature_columns = preprocess_config['feature_columns']
print(f'feature 수: {len(feature_columns):,}')
# Out:
#                 name                                               path  \
# 0              train  data/processed/original_train_train_preprocess...
# 1                val  data/processed/original_train_val_preprocessed...
# 2               test  data/processed/original_train_test_preprocesse...
# 3  preprocess_config  artifacts/preprocessors/original_train_preproc...
# 4         docs_table                                   docs/기법별_성능평가.md
#
#    exists
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# feature 수: 102

# %%
def accident_target(frame: pd.DataFrame) -> pd.Series:
    """위험도 값을 모델 1의 사고발생 이진 라벨로 변환한다."""
    return (frame['위험도'] > 0).astype(int)


train_frame = pd.read_csv(TRAIN_PATH, nrows=ROW_LIMIT)
X_train = train_frame[feature_columns]
y_train = accident_target(train_frame)

print('sampling 실행 전 클래스 분포')
display(y_train.value_counts().rename(index={0: '사고발생=0', 1: '사고발생=1'}).to_frame('count'))

sampler = OneSidedSelection(random_state=RANDOM_STATE, n_jobs=-1)
print(sampler)

if RUN_SAMPLING:
    X_resampled, y_resampled = sampler.fit_resample(X_train, y_train)
    sampled_train = pd.DataFrame(X_resampled, columns=feature_columns)

    # 모델 1 학습 스크립트는 위험도 > 0 여부만 사용하므로, sampling 후 라벨 복원을 위해 위험도 컬럼을 만든다.
    sampled_train['위험도'] = np.where(np.asarray(y_resampled) == 1, 1.0, 0.0)

    SAMPLED_INPUT_DIR.mkdir(parents=True, exist_ok=True)
    sampled_train.to_csv(SAMPLED_TRAIN_PATH, index=False)

    print('sampling 실행 후 클래스 분포')
    display(pd.Series(y_resampled).value_counts().rename(index={0: '사고발생=0', 1: '사고발생=1'}).to_frame('count'))
    print(f'sampled train 저장: {SAMPLED_TRAIN_PATH.relative_to(PROJECT_ROOT)}')
else:
    print('RUN_SAMPLING=False 상태입니다. 실제 sampling CSV 생성은 실행하지 않았습니다.')
    print('실행하려면 위 설정 셀에서 RUN_SAMPLING=True로 변경하십시오.')
# Out:
# sampling 실행 전 클래스 분포
#          count
# 위험도
# 사고발생=0  252551
# 사고발생=1   62913
# OneSidedSelection(n_jobs=-1, random_state=42)
# /tmp/ipykernel_23373/4162942622.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sampled_train['위험도'] = np.where(np.asarray(y_resampled) == 1, 1.0, 0.0)
# sampling 실행 후 클래스 분포
#          count
# 위험도
# 사고발생=0  247968
# 사고발생=1   62913
# sampled train 저장: artifacts/experiments/sampling_inputs/one_sided_selection_two_stage_model1_train_preprocessed.csv

# %%
model1_command = [
    sys.executable,
    str(PROJECT_ROOT / 'scripts' / 'train' / 'train_accident_classifier.py'),
    '--train', str(SAMPLED_TRAIN_PATH),
    '--val', str(VAL_PATH),
    '--test', str(TEST_PATH),
    '--model-path', str(MODEL1_MODEL_PATH),
    '--metrics-path', str(MODEL1_METRICS_PATH),
    '--history-path', str(MODEL1_HISTORY_PATH),
    '--predictions-path', str(MODEL1_PREDICTIONS_PATH),
    '--epochs', '100',
    '--batch-size', '1024',
    '--device', 'auto',
    '--verbose', '2',
    '--top-k', '1000',
]

print('모델 1 학습 명령:')
print(' '.join(model1_command))

if RUN_TRAINING:
    if not SAMPLED_TRAIN_PATH.exists():
        raise FileNotFoundError('모델 1 학습 전 RUN_SAMPLING=True로 sampling train CSV를 먼저 생성해야 합니다.')
    subprocess.run(model1_command, check=True)
else:
    print('RUN_TRAINING=False 상태입니다. 실제 모델 1 학습은 실행하지 않았습니다.')
# Out:
# 모델 1 학습 명령:
# /home/huichan/SPARV/SilverWalk/.venv/bin/python /home/huichan/SPARV/SilverWalk/scripts/train/train_accident_classifier.py --train /home/huichan/SPARV/SilverWalk/artifacts/experiments/sampling_inputs/one_sided_selection_two_stage_model1_train_preprocessed.csv --val /home/huichan/SPARV/SilverWalk/data/processed/original_train_val_preprocessed.csv --test /home/huichan/SPARV/SilverWalk/data/processed/original_train_test_preprocessed.csv --model-path /home/huichan/SPARV/SilverWalk/artifacts/models/mlp_accident_classifier_one_sided_selection_two_stage.keras --metrics-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_accident_classifier_one_sided_selection_two_stage_metrics.json --history-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_accident_classifier_one_sided_selection_two_stage_history.csv --predictions-path /home/huichan/SPARV/SilverWalk/artifacts/predictions/mlp_accident_classifier_one_sided_selection_two_stage_test_predictions.csv --epochs 100 --batch-size 1024 --device auto --verbose 2 --top-k 1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780781225.796123   23968 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780781225.838172   23968 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780781226.699885   23968 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# W0000 00:00:1780781227.497281   23968 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/100
# 304/304 - 3s - 8ms/step - accuracy: 0.8025 - loss: 0.4417 - pr_auc: 0.4286 - precision: 0.5266 - recall: 0.2403 - roc_auc: 0.7480 - val_accuracy: 0.8210 - val_loss: 0.4103 - val_pr_auc: 0.5028 - val_precision: 0.6370 - val_recall: 0.2383 - val_roc_auc: 0.7860 - learning_rate: 0.0010
# Epoch 2/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8175 - loss: 0.4143 - pr_auc: 0.5024 - precision: 0.6141 - recall: 0.2647 - roc_auc: 0.7842 - val_accuracy: 0.8244 - val_loss: 0.4003 - val_pr_auc: 0.5250 - val_precision: 0.6505 - val_recall: 0.2581 - val_roc_auc: 0.7999 - learning_rate: 0.0010
# Epoch 3/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8219 - loss: 0.4044 - pr_auc: 0.5245 - precision: 0.6325 - recall: 0.2865 - roc_auc: 0.7979 - val_accuracy: 0.8281 - val_loss: 0.3914 - val_pr_auc: 0.5457 - val_precision: 0.6715 - val_recall: 0.2701 - val_roc_auc: 0.8119 - learning_rate: 0.0010
# Epoch 4/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8246 - loss: 0.3977 - pr_auc: 0.5393 - precision: 0.6400 - recall: 0.3048 - roc_auc: 0.8070 - val_accuracy: 0.8302 - val_loss: 0.3846 - val_pr_auc: 0.5604 - val_precision: 0.6812 - val_recall: 0.2790 - val_roc_auc: 0.8207 - learning_rate: 0.0010
# Epoch 5/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8270 - loss: 0.3913 - pr_auc: 0.5534 - precision: 0.6453 - recall: 0.3229 - roc_auc: 0.8150 - val_accuracy: 0.8336 - val_loss: 0.3783 - val_pr_auc: 0.5739 - val_precision: 0.6950 - val_recall: 0.2950 - val_roc_auc: 0.8283 - learning_rate: 0.0010
# Epoch 6/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8299 - loss: 0.3854 - pr_auc: 0.5675 - precision: 0.6539 - recall: 0.3389 - roc_auc: 0.8219 - val_accuracy: 0.8366 - val_loss: 0.3722 - val_pr_auc: 0.5858 - val_precision: 0.6914 - val_recall: 0.3265 - val_roc_auc: 0.8348 - learning_rate: 0.0010
# Epoch 7/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8316 - loss: 0.3807 - pr_auc: 0.5757 - precision: 0.6568 - recall: 0.3513 - roc_auc: 0.8278 - val_accuracy: 0.8384 - val_loss: 0.3665 - val_pr_auc: 0.5979 - val_precision: 0.6967 - val_recall: 0.3358 - val_roc_auc: 0.8417 - learning_rate: 0.0010
# Epoch 8/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8345 - loss: 0.3758 - pr_auc: 0.5871 - precision: 0.6638 - recall: 0.3687 - roc_auc: 0.8331 - val_accuracy: 0.8406 - val_loss: 0.3617 - val_pr_auc: 0.6069 - val_precision: 0.6909 - val_recall: 0.3631 - val_roc_auc: 0.8466 - learning_rate: 0.0010
# Epoch 9/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8352 - loss: 0.3723 - pr_auc: 0.5936 - precision: 0.6643 - recall: 0.3754 - roc_auc: 0.8372 - val_accuracy: 0.8437 - val_loss: 0.3566 - val_pr_auc: 0.6171 - val_precision: 0.7046 - val_recall: 0.3719 - val_roc_auc: 0.8524 - learning_rate: 0.0010
# Epoch 10/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8378 - loss: 0.3684 - pr_auc: 0.6027 - precision: 0.6705 - recall: 0.3901 - roc_auc: 0.8412 - val_accuracy: 0.8440 - val_loss: 0.3533 - val_pr_auc: 0.6247 - val_precision: 0.7092 - val_recall: 0.3693 - val_roc_auc: 0.8557 - learning_rate: 0.0010
# Epoch 11/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8387 - loss: 0.3651 - pr_auc: 0.6083 - precision: 0.6716 - recall: 0.3972 - roc_auc: 0.8449 - val_accuracy: 0.8455 - val_loss: 0.3499 - val_pr_auc: 0.6314 - val_precision: 0.7084 - val_recall: 0.3825 - val_roc_auc: 0.8589 - learning_rate: 0.0010
# Epoch 12/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8406 - loss: 0.3618 - pr_auc: 0.6157 - precision: 0.6764 - recall: 0.4066 - roc_auc: 0.8484 - val_accuracy: 0.8471 - val_loss: 0.3468 - val_pr_auc: 0.6363 - val_precision: 0.7044 - val_recall: 0.4017 - val_roc_auc: 0.8624 - learning_rate: 0.0010
# Epoch 13/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8417 - loss: 0.3589 - pr_auc: 0.6214 - precision: 0.6774 - recall: 0.4154 - roc_auc: 0.8512 - val_accuracy: 0.8495 - val_loss: 0.3433 - val_pr_auc: 0.6443 - val_precision: 0.7091 - val_recall: 0.4157 - val_roc_auc: 0.8653 - learning_rate: 0.0010
# Epoch 14/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8418 - loss: 0.3573 - pr_auc: 0.6235 - precision: 0.6772 - recall: 0.4173 - roc_auc: 0.8531 - val_accuracy: 0.8494 - val_loss: 0.3400 - val_pr_auc: 0.6510 - val_precision: 0.7159 - val_recall: 0.4062 - val_roc_auc: 0.8690 - learning_rate: 0.0010
# Epoch 15/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8444 - loss: 0.3539 - pr_auc: 0.6315 - precision: 0.6838 - recall: 0.4299 - roc_auc: 0.8562 - val_accuracy: 0.8524 - val_loss: 0.3378 - val_pr_auc: 0.6553 - val_precision: 0.7251 - val_recall: 0.4182 - val_roc_auc: 0.8707 - learning_rate: 0.0010
# Epoch 16/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8454 - loss: 0.3521 - pr_auc: 0.6351 - precision: 0.6867 - recall: 0.4345 - roc_auc: 0.8580 - val_accuracy: 0.8520 - val_loss: 0.3365 - val_pr_auc: 0.6570 - val_precision: 0.7256 - val_recall: 0.4144 - val_roc_auc: 0.8720 - learning_rate: 0.0010
# Epoch 17/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8455 - loss: 0.3504 - pr_auc: 0.6385 - precision: 0.6857 - recall: 0.4366 - roc_auc: 0.8596 - val_accuracy: 0.8526 - val_loss: 0.3346 - val_pr_auc: 0.6622 - val_precision: 0.7338 - val_recall: 0.4096 - val_roc_auc: 0.8747 - learning_rate: 0.0010
# Epoch 18/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8470 - loss: 0.3488 - pr_auc: 0.6418 - precision: 0.6903 - recall: 0.4424 - roc_auc: 0.8612 - val_accuracy: 0.8540 - val_loss: 0.3323 - val_pr_auc: 0.6654 - val_precision: 0.7293 - val_recall: 0.4258 - val_roc_auc: 0.8762 - learning_rate: 0.0010
# Epoch 19/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8470 - loss: 0.3474 - pr_auc: 0.6438 - precision: 0.6881 - recall: 0.4465 - roc_auc: 0.8627 - val_accuracy: 0.8555 - val_loss: 0.3310 - val_pr_auc: 0.6674 - val_precision: 0.7273 - val_recall: 0.4408 - val_roc_auc: 0.8765 - learning_rate: 0.0010
# Epoch 20/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8478 - loss: 0.3453 - pr_auc: 0.6475 - precision: 0.6890 - recall: 0.4522 - roc_auc: 0.8648 - val_accuracy: 0.8569 - val_loss: 0.3284 - val_pr_auc: 0.6722 - val_precision: 0.7349 - val_recall: 0.4420 - val_roc_auc: 0.8794 - learning_rate: 0.0010
# Epoch 21/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8482 - loss: 0.3447 - pr_auc: 0.6498 - precision: 0.6904 - recall: 0.4527 - roc_auc: 0.8650 - val_accuracy: 0.8574 - val_loss: 0.3276 - val_pr_auc: 0.6744 - val_precision: 0.7358 - val_recall: 0.4444 - val_roc_auc: 0.8799 - learning_rate: 0.0010
# Epoch 22/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8496 - loss: 0.3429 - pr_auc: 0.6539 - precision: 0.6940 - recall: 0.4595 - roc_auc: 0.8667 - val_accuracy: 0.8571 - val_loss: 0.3265 - val_pr_auc: 0.6757 - val_precision: 0.7392 - val_recall: 0.4382 - val_roc_auc: 0.8813 - learning_rate: 0.0010
# Epoch 23/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8504 - loss: 0.3417 - pr_auc: 0.6562 - precision: 0.6956 - recall: 0.4637 - roc_auc: 0.8677 - val_accuracy: 0.8569 - val_loss: 0.3261 - val_pr_auc: 0.6769 - val_precision: 0.7402 - val_recall: 0.4354 - val_roc_auc: 0.8821 - learning_rate: 0.0010
# Epoch 24/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8506 - loss: 0.3404 - pr_auc: 0.6577 - precision: 0.6950 - recall: 0.4666 - roc_auc: 0.8691 - val_accuracy: 0.8581 - val_loss: 0.3238 - val_pr_auc: 0.6797 - val_precision: 0.7359 - val_recall: 0.4500 - val_roc_auc: 0.8840 - learning_rate: 0.0010
# Epoch 25/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8505 - loss: 0.3392 - pr_auc: 0.6594 - precision: 0.6939 - recall: 0.4672 - roc_auc: 0.8704 - val_accuracy: 0.8583 - val_loss: 0.3228 - val_pr_auc: 0.6823 - val_precision: 0.7354 - val_recall: 0.4517 - val_roc_auc: 0.8846 - learning_rate: 0.0010
# Epoch 26/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8519 - loss: 0.3378 - pr_auc: 0.6631 - precision: 0.6990 - recall: 0.4709 - roc_auc: 0.8715 - val_accuracy: 0.8601 - val_loss: 0.3214 - val_pr_auc: 0.6849 - val_precision: 0.7309 - val_recall: 0.4724 - val_roc_auc: 0.8857 - learning_rate: 0.0010
# Epoch 27/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8525 - loss: 0.3364 - pr_auc: 0.6644 - precision: 0.6990 - recall: 0.4765 - roc_auc: 0.8730 - val_accuracy: 0.8605 - val_loss: 0.3206 - val_pr_auc: 0.6869 - val_precision: 0.7393 - val_recall: 0.4645 - val_roc_auc: 0.8860 - learning_rate: 0.0010
# Epoch 28/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8529 - loss: 0.3356 - pr_auc: 0.6674 - precision: 0.7013 - recall: 0.4756 - roc_auc: 0.8734 - val_accuracy: 0.8616 - val_loss: 0.3194 - val_pr_auc: 0.6897 - val_precision: 0.7393 - val_recall: 0.4728 - val_roc_auc: 0.8871 - learning_rate: 0.0010
# Epoch 29/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8532 - loss: 0.3348 - pr_auc: 0.6687 - precision: 0.7011 - recall: 0.4784 - roc_auc: 0.8741 - val_accuracy: 0.8613 - val_loss: 0.3179 - val_pr_auc: 0.6924 - val_precision: 0.7426 - val_recall: 0.4658 - val_roc_auc: 0.8891 - learning_rate: 0.0010
# Epoch 30/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8535 - loss: 0.3337 - pr_auc: 0.6703 - precision: 0.7010 - recall: 0.4813 - roc_auc: 0.8751 - val_accuracy: 0.8612 - val_loss: 0.3174 - val_pr_auc: 0.6928 - val_precision: 0.7462 - val_recall: 0.4608 - val_roc_auc: 0.8893 - learning_rate: 0.0010
# Epoch 31/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8542 - loss: 0.3335 - pr_auc: 0.6715 - precision: 0.7038 - recall: 0.4825 - roc_auc: 0.8752 - val_accuracy: 0.8625 - val_loss: 0.3166 - val_pr_auc: 0.6945 - val_precision: 0.7493 - val_recall: 0.4670 - val_roc_auc: 0.8896 - learning_rate: 0.0010
# Epoch 32/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8543 - loss: 0.3321 - pr_auc: 0.6726 - precision: 0.7039 - recall: 0.4836 - roc_auc: 0.8767 - val_accuracy: 0.8621 - val_loss: 0.3155 - val_pr_auc: 0.6947 - val_precision: 0.7426 - val_recall: 0.4718 - val_roc_auc: 0.8910 - learning_rate: 0.0010
# Epoch 33/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8548 - loss: 0.3318 - pr_auc: 0.6743 - precision: 0.7048 - recall: 0.4861 - roc_auc: 0.8769 - val_accuracy: 0.8637 - val_loss: 0.3134 - val_pr_auc: 0.6979 - val_precision: 0.7363 - val_recall: 0.4928 - val_roc_auc: 0.8920 - learning_rate: 0.0010
# Epoch 34/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8546 - loss: 0.3312 - pr_auc: 0.6750 - precision: 0.7025 - recall: 0.4880 - roc_auc: 0.8774 - val_accuracy: 0.8633 - val_loss: 0.3139 - val_pr_auc: 0.6984 - val_precision: 0.7446 - val_recall: 0.4785 - val_roc_auc: 0.8917 - learning_rate: 0.0010
# Epoch 35/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8550 - loss: 0.3301 - pr_auc: 0.6765 - precision: 0.7037 - recall: 0.4900 - roc_auc: 0.8785 - val_accuracy: 0.8635 - val_loss: 0.3127 - val_pr_auc: 0.6994 - val_precision: 0.7443 - val_recall: 0.4810 - val_roc_auc: 0.8930 - learning_rate: 0.0010
# Epoch 36/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8559 - loss: 0.3298 - pr_auc: 0.6781 - precision: 0.7058 - recall: 0.4934 - roc_auc: 0.8785 - val_accuracy: 0.8627 - val_loss: 0.3127 - val_pr_auc: 0.6995 - val_precision: 0.7422 - val_recall: 0.4771 - val_roc_auc: 0.8933 - learning_rate: 0.0010
# Epoch 37/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8561 - loss: 0.3283 - pr_auc: 0.6804 - precision: 0.7064 - recall: 0.4943 - roc_auc: 0.8798 - val_accuracy: 0.8637 - val_loss: 0.3110 - val_pr_auc: 0.7035 - val_precision: 0.7445 - val_recall: 0.4816 - val_roc_auc: 0.8941 - learning_rate: 0.0010
# Epoch 38/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8562 - loss: 0.3284 - pr_auc: 0.6805 - precision: 0.7066 - recall: 0.4950 - roc_auc: 0.8797 - val_accuracy: 0.8640 - val_loss: 0.3106 - val_pr_auc: 0.7032 - val_precision: 0.7467 - val_recall: 0.4811 - val_roc_auc: 0.8950 - learning_rate: 0.0010
# Epoch 39/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8558 - loss: 0.3273 - pr_auc: 0.6820 - precision: 0.7052 - recall: 0.4938 - roc_auc: 0.8808 - val_accuracy: 0.8643 - val_loss: 0.3102 - val_pr_auc: 0.7039 - val_precision: 0.7381 - val_recall: 0.4952 - val_roc_auc: 0.8946 - learning_rate: 0.0010
# Epoch 40/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8560 - loss: 0.3268 - pr_auc: 0.6830 - precision: 0.7057 - recall: 0.4946 - roc_auc: 0.8812 - val_accuracy: 0.8636 - val_loss: 0.3093 - val_pr_auc: 0.7052 - val_precision: 0.7437 - val_recall: 0.4823 - val_roc_auc: 0.8959 - learning_rate: 0.0010
# Epoch 41/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8578 - loss: 0.3259 - pr_auc: 0.6846 - precision: 0.7098 - recall: 0.5026 - roc_auc: 0.8820 - val_accuracy: 0.8641 - val_loss: 0.3084 - val_pr_auc: 0.7072 - val_precision: 0.7497 - val_recall: 0.4784 - val_roc_auc: 0.8970 - learning_rate: 0.0010
# Epoch 42/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8573 - loss: 0.3258 - pr_auc: 0.6844 - precision: 0.7091 - recall: 0.4999 - roc_auc: 0.8821 - val_accuracy: 0.8646 - val_loss: 0.3090 - val_pr_auc: 0.7070 - val_precision: 0.7544 - val_recall: 0.4760 - val_roc_auc: 0.8961 - learning_rate: 0.0010
# Epoch 43/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8570 - loss: 0.3257 - pr_auc: 0.6839 - precision: 0.7065 - recall: 0.5016 - roc_auc: 0.8824 - val_accuracy: 0.8663 - val_loss: 0.3078 - val_pr_auc: 0.7079 - val_precision: 0.7393 - val_recall: 0.5092 - val_roc_auc: 0.8964 - learning_rate: 0.0010
# Epoch 44/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8586 - loss: 0.3240 - pr_auc: 0.6878 - precision: 0.7107 - recall: 0.5084 - roc_auc: 0.8836 - val_accuracy: 0.8663 - val_loss: 0.3079 - val_pr_auc: 0.7066 - val_precision: 0.7379 - val_recall: 0.5112 - val_roc_auc: 0.8964 - learning_rate: 0.0010
# Epoch 45/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8573 - loss: 0.3244 - pr_auc: 0.6874 - precision: 0.7064 - recall: 0.5046 - roc_auc: 0.8832 - val_accuracy: 0.8659 - val_loss: 0.3086 - val_pr_auc: 0.7059 - val_precision: 0.7415 - val_recall: 0.5029 - val_roc_auc: 0.8964 - learning_rate: 0.0010
# Epoch 46/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8580 - loss: 0.3234 - pr_auc: 0.6879 - precision: 0.7085 - recall: 0.5067 - roc_auc: 0.8842 - val_accuracy: 0.8652 - val_loss: 0.3063 - val_pr_auc: 0.7097 - val_precision: 0.7423 - val_recall: 0.4962 - val_roc_auc: 0.8982 - learning_rate: 0.0010
# Epoch 47/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8595 - loss: 0.3219 - pr_auc: 0.6926 - precision: 0.7123 - recall: 0.5124 - roc_auc: 0.8852 - val_accuracy: 0.8664 - val_loss: 0.3061 - val_pr_auc: 0.7109 - val_precision: 0.7492 - val_recall: 0.4964 - val_roc_auc: 0.8982 - learning_rate: 0.0010
# Epoch 48/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8588 - loss: 0.3226 - pr_auc: 0.6902 - precision: 0.7104 - recall: 0.5099 - roc_auc: 0.8849 - val_accuracy: 0.8664 - val_loss: 0.3058 - val_pr_auc: 0.7126 - val_precision: 0.7449 - val_recall: 0.5024 - val_roc_auc: 0.8981 - learning_rate: 0.0010
# Epoch 49/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8592 - loss: 0.3220 - pr_auc: 0.6916 - precision: 0.7124 - recall: 0.5106 - roc_auc: 0.8854 - val_accuracy: 0.8672 - val_loss: 0.3043 - val_pr_auc: 0.7146 - val_precision: 0.7385 - val_recall: 0.5170 - val_roc_auc: 0.8993 - learning_rate: 0.0010
# Epoch 50/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8591 - loss: 0.3222 - pr_auc: 0.6915 - precision: 0.7102 - recall: 0.5129 - roc_auc: 0.8850 - val_accuracy: 0.8668 - val_loss: 0.3045 - val_pr_auc: 0.7134 - val_precision: 0.7433 - val_recall: 0.5073 - val_roc_auc: 0.8997 - learning_rate: 0.0010
# Epoch 51/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8596 - loss: 0.3211 - pr_auc: 0.6932 - precision: 0.7120 - recall: 0.5138 - roc_auc: 0.8861 - val_accuracy: 0.8670 - val_loss: 0.3040 - val_pr_auc: 0.7153 - val_precision: 0.7512 - val_recall: 0.4981 - val_roc_auc: 0.8998 - learning_rate: 0.0010
# Epoch 52/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8603 - loss: 0.3197 - pr_auc: 0.6956 - precision: 0.7140 - recall: 0.5163 - roc_auc: 0.8872 - val_accuracy: 0.8679 - val_loss: 0.3038 - val_pr_auc: 0.7144 - val_precision: 0.7467 - val_recall: 0.5111 - val_roc_auc: 0.8999 - learning_rate: 0.0010
# Epoch 53/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8604 - loss: 0.3197 - pr_auc: 0.6959 - precision: 0.7139 - recall: 0.5178 - roc_auc: 0.8873 - val_accuracy: 0.8677 - val_loss: 0.3025 - val_pr_auc: 0.7156 - val_precision: 0.7431 - val_recall: 0.5148 - val_roc_auc: 0.9009 - learning_rate: 0.0010
# Epoch 54/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8606 - loss: 0.3190 - pr_auc: 0.6963 - precision: 0.7146 - recall: 0.5182 - roc_auc: 0.8880 - val_accuracy: 0.8672 - val_loss: 0.3023 - val_pr_auc: 0.7155 - val_precision: 0.7426 - val_recall: 0.5117 - val_roc_auc: 0.9011 - learning_rate: 0.0010
# Epoch 55/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8601 - loss: 0.3192 - pr_auc: 0.6958 - precision: 0.7116 - recall: 0.5193 - roc_auc: 0.8877 - val_accuracy: 0.8671 - val_loss: 0.3024 - val_pr_auc: 0.7167 - val_precision: 0.7484 - val_recall: 0.5029 - val_roc_auc: 0.9010 - learning_rate: 0.0010
# Epoch 56/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8607 - loss: 0.3189 - pr_auc: 0.6971 - precision: 0.7146 - recall: 0.5192 - roc_auc: 0.8878 - val_accuracy: 0.8679 - val_loss: 0.3016 - val_pr_auc: 0.7185 - val_precision: 0.7526 - val_recall: 0.5028 - val_roc_auc: 0.9020 - learning_rate: 0.0010
# Epoch 57/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8612 - loss: 0.3183 - pr_auc: 0.6978 - precision: 0.7155 - recall: 0.5215 - roc_auc: 0.8884 - val_accuracy: 0.8683 - val_loss: 0.3016 - val_pr_auc: 0.7184 - val_precision: 0.7458 - val_recall: 0.5150 - val_roc_auc: 0.9016 - learning_rate: 0.0010
# Epoch 58/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8611 - loss: 0.3176 - pr_auc: 0.6992 - precision: 0.7147 - recall: 0.5224 - roc_auc: 0.8890 - val_accuracy: 0.8685 - val_loss: 0.3007 - val_pr_auc: 0.7199 - val_precision: 0.7452 - val_recall: 0.5173 - val_roc_auc: 0.9019 - learning_rate: 0.0010
# Epoch 59/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8606 - loss: 0.3188 - pr_auc: 0.6972 - precision: 0.7137 - recall: 0.5199 - roc_auc: 0.8879 - val_accuracy: 0.8697 - val_loss: 0.2990 - val_pr_auc: 0.7227 - val_precision: 0.7429 - val_recall: 0.5298 - val_roc_auc: 0.9031 - learning_rate: 0.0010
# Epoch 60/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8615 - loss: 0.3177 - pr_auc: 0.7005 - precision: 0.7159 - recall: 0.5230 - roc_auc: 0.8887 - val_accuracy: 0.8700 - val_loss: 0.2990 - val_pr_auc: 0.7238 - val_precision: 0.7538 - val_recall: 0.5170 - val_roc_auc: 0.9040 - learning_rate: 0.0010
# Epoch 61/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8617 - loss: 0.3167 - pr_auc: 0.7012 - precision: 0.7170 - recall: 0.5227 - roc_auc: 0.8897 - val_accuracy: 0.8683 - val_loss: 0.2998 - val_pr_auc: 0.7208 - val_precision: 0.7429 - val_recall: 0.5195 - val_roc_auc: 0.9028 - learning_rate: 0.0010
# Epoch 62/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8622 - loss: 0.3166 - pr_auc: 0.7012 - precision: 0.7190 - recall: 0.5235 - roc_auc: 0.8897 - val_accuracy: 0.8687 - val_loss: 0.2991 - val_pr_auc: 0.7228 - val_precision: 0.7522 - val_recall: 0.5095 - val_roc_auc: 0.9038 - learning_rate: 0.0010
# Epoch 63/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8617 - loss: 0.3168 - pr_auc: 0.7005 - precision: 0.7162 - recall: 0.5246 - roc_auc: 0.8897 - val_accuracy: 0.8695 - val_loss: 0.2981 - val_pr_auc: 0.7240 - val_precision: 0.7451 - val_recall: 0.5255 - val_roc_auc: 0.9044 - learning_rate: 0.0010
# Epoch 64/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8616 - loss: 0.3166 - pr_auc: 0.7015 - precision: 0.7158 - recall: 0.5243 - roc_auc: 0.8897 - val_accuracy: 0.8701 - val_loss: 0.2973 - val_pr_auc: 0.7260 - val_precision: 0.7489 - val_recall: 0.5244 - val_roc_auc: 0.9051 - learning_rate: 0.0010
# Epoch 65/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8627 - loss: 0.3147 - pr_auc: 0.7040 - precision: 0.7180 - recall: 0.5293 - roc_auc: 0.8913 - val_accuracy: 0.8699 - val_loss: 0.2976 - val_pr_auc: 0.7247 - val_precision: 0.7480 - val_recall: 0.5239 - val_roc_auc: 0.9046 - learning_rate: 0.0010
# Epoch 66/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8627 - loss: 0.3149 - pr_auc: 0.7048 - precision: 0.7187 - recall: 0.5284 - roc_auc: 0.8909 - val_accuracy: 0.8695 - val_loss: 0.2977 - val_pr_auc: 0.7257 - val_precision: 0.7457 - val_recall: 0.5244 - val_roc_auc: 0.9046 - learning_rate: 0.0010
# Epoch 67/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8624 - loss: 0.3152 - pr_auc: 0.7037 - precision: 0.7168 - recall: 0.5291 - roc_auc: 0.8908 - val_accuracy: 0.8697 - val_loss: 0.2968 - val_pr_auc: 0.7268 - val_precision: 0.7504 - val_recall: 0.5192 - val_roc_auc: 0.9054 - learning_rate: 0.0010
# Epoch 68/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8620 - loss: 0.3154 - pr_auc: 0.7020 - precision: 0.7177 - recall: 0.5243 - roc_auc: 0.8910 - val_accuracy: 0.8706 - val_loss: 0.2971 - val_pr_auc: 0.7270 - val_precision: 0.7533 - val_recall: 0.5223 - val_roc_auc: 0.9051 - learning_rate: 0.0010
# Epoch 69/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8633 - loss: 0.3138 - pr_auc: 0.7065 - precision: 0.7199 - recall: 0.5313 - roc_auc: 0.8919 - val_accuracy: 0.8703 - val_loss: 0.2962 - val_pr_auc: 0.7285 - val_precision: 0.7588 - val_recall: 0.5128 - val_roc_auc: 0.9059 - learning_rate: 0.0010
# Epoch 70/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8634 - loss: 0.3134 - pr_auc: 0.7074 - precision: 0.7200 - recall: 0.5316 - roc_auc: 0.8921 - val_accuracy: 0.8706 - val_loss: 0.2966 - val_pr_auc: 0.7274 - val_precision: 0.7553 - val_recall: 0.5194 - val_roc_auc: 0.9056 - learning_rate: 0.0010
# Epoch 71/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8634 - loss: 0.3134 - pr_auc: 0.7063 - precision: 0.7194 - recall: 0.5327 - roc_auc: 0.8924 - val_accuracy: 0.8713 - val_loss: 0.2953 - val_pr_auc: 0.7296 - val_precision: 0.7509 - val_recall: 0.5310 - val_roc_auc: 0.9063 - learning_rate: 0.0010
# Epoch 72/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8634 - loss: 0.3127 - pr_auc: 0.7079 - precision: 0.7197 - recall: 0.5325 - roc_auc: 0.8928 - val_accuracy: 0.8705 - val_loss: 0.2963 - val_pr_auc: 0.7277 - val_precision: 0.7565 - val_recall: 0.5170 - val_roc_auc: 0.9059 - learning_rate: 0.0010
# Epoch 73/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8638 - loss: 0.3128 - pr_auc: 0.7076 - precision: 0.7213 - recall: 0.5326 - roc_auc: 0.8927 - val_accuracy: 0.8706 - val_loss: 0.2960 - val_pr_auc: 0.7285 - val_precision: 0.7549 - val_recall: 0.5196 - val_roc_auc: 0.9063 - learning_rate: 0.0010
# Epoch 74/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8644 - loss: 0.3119 - pr_auc: 0.7094 - precision: 0.7220 - recall: 0.5368 - roc_auc: 0.8934 - val_accuracy: 0.8713 - val_loss: 0.2957 - val_pr_auc: 0.7293 - val_precision: 0.7563 - val_recall: 0.5233 - val_roc_auc: 0.9060 - learning_rate: 0.0010
# Epoch 75/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8631 - loss: 0.3138 - pr_auc: 0.7067 - precision: 0.7190 - recall: 0.5307 - roc_auc: 0.8919 - val_accuracy: 0.8722 - val_loss: 0.2948 - val_pr_auc: 0.7308 - val_precision: 0.7554 - val_recall: 0.5310 - val_roc_auc: 0.9065 - learning_rate: 0.0010
# Epoch 76/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8643 - loss: 0.3119 - pr_auc: 0.7088 - precision: 0.7214 - recall: 0.5366 - roc_auc: 0.8936 - val_accuracy: 0.8726 - val_loss: 0.2942 - val_pr_auc: 0.7317 - val_precision: 0.7563 - val_recall: 0.5330 - val_roc_auc: 0.9070 - learning_rate: 0.0010
# Epoch 77/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8631 - loss: 0.3124 - pr_auc: 0.7067 - precision: 0.7173 - recall: 0.5338 - roc_auc: 0.8934 - val_accuracy: 0.8708 - val_loss: 0.2954 - val_pr_auc: 0.7296 - val_precision: 0.7557 - val_recall: 0.5204 - val_roc_auc: 0.9064 - learning_rate: 0.0010
# Epoch 78/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8647 - loss: 0.3105 - pr_auc: 0.7125 - precision: 0.7211 - recall: 0.5405 - roc_auc: 0.8944 - val_accuracy: 0.8715 - val_loss: 0.2945 - val_pr_auc: 0.7303 - val_precision: 0.7487 - val_recall: 0.5356 - val_roc_auc: 0.9068 - learning_rate: 0.0010
# Epoch 79/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8648 - loss: 0.3104 - pr_auc: 0.7126 - precision: 0.7224 - recall: 0.5394 - roc_auc: 0.8945 - val_accuracy: 0.8714 - val_loss: 0.2939 - val_pr_auc: 0.7310 - val_precision: 0.7486 - val_recall: 0.5350 - val_roc_auc: 0.9072 - learning_rate: 0.0010
# Epoch 80/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8650 - loss: 0.3115 - pr_auc: 0.7101 - precision: 0.7232 - recall: 0.5393 - roc_auc: 0.8938 - val_accuracy: 0.8717 - val_loss: 0.2942 - val_pr_auc: 0.7318 - val_precision: 0.7549 - val_recall: 0.5281 - val_roc_auc: 0.9074 - learning_rate: 0.0010
# Epoch 81/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8644 - loss: 0.3112 - pr_auc: 0.7102 - precision: 0.7214 - recall: 0.5373 - roc_auc: 0.8942 - val_accuracy: 0.8720 - val_loss: 0.2933 - val_pr_auc: 0.7337 - val_precision: 0.7572 - val_recall: 0.5270 - val_roc_auc: 0.9076 - learning_rate: 0.0010
# Epoch 82/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8652 - loss: 0.3105 - pr_auc: 0.7117 - precision: 0.7234 - recall: 0.5403 - roc_auc: 0.8945 - val_accuracy: 0.8725 - val_loss: 0.2932 - val_pr_auc: 0.7340 - val_precision: 0.7521 - val_recall: 0.5383 - val_roc_auc: 0.9075 - learning_rate: 0.0010
# Epoch 83/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8650 - loss: 0.3105 - pr_auc: 0.7119 - precision: 0.7225 - recall: 0.5404 - roc_auc: 0.8946 - val_accuracy: 0.8723 - val_loss: 0.2933 - val_pr_auc: 0.7332 - val_precision: 0.7548 - val_recall: 0.5330 - val_roc_auc: 0.9074 - learning_rate: 0.0010
# Epoch 84/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8657 - loss: 0.3095 - pr_auc: 0.7142 - precision: 0.7245 - recall: 0.5431 - roc_auc: 0.8952 - val_accuracy: 0.8719 - val_loss: 0.2936 - val_pr_auc: 0.7334 - val_precision: 0.7567 - val_recall: 0.5273 - val_roc_auc: 0.9073 - learning_rate: 0.0010
# Epoch 85/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8652 - loss: 0.3096 - pr_auc: 0.7135 - precision: 0.7226 - recall: 0.5417 - roc_auc: 0.8953 - val_accuracy: 0.8727 - val_loss: 0.2927 - val_pr_auc: 0.7333 - val_precision: 0.7498 - val_recall: 0.5429 - val_roc_auc: 0.9079 - learning_rate: 0.0010
# Epoch 86/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8648 - loss: 0.3105 - pr_auc: 0.7119 - precision: 0.7222 - recall: 0.5395 - roc_auc: 0.8945 - val_accuracy: 0.8715 - val_loss: 0.2935 - val_pr_auc: 0.7338 - val_precision: 0.7599 - val_recall: 0.5198 - val_roc_auc: 0.9078 - learning_rate: 0.0010
# Epoch 87/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8676 - loss: 0.3048 - pr_auc: 0.7206 - precision: 0.7285 - recall: 0.5510 - roc_auc: 0.8992 - val_accuracy: 0.8746 - val_loss: 0.2888 - val_pr_auc: 0.7396 - val_precision: 0.7441 - val_recall: 0.5660 - val_roc_auc: 0.9106 - learning_rate: 5.0000e-04
# Epoch 88/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8679 - loss: 0.3044 - pr_auc: 0.7216 - precision: 0.7289 - recall: 0.5529 - roc_auc: 0.8993 - val_accuracy: 0.8744 - val_loss: 0.2886 - val_pr_auc: 0.7402 - val_precision: 0.7503 - val_recall: 0.5546 - val_roc_auc: 0.9106 - learning_rate: 5.0000e-04
# Epoch 89/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8685 - loss: 0.3039 - pr_auc: 0.7229 - precision: 0.7298 - recall: 0.5561 - roc_auc: 0.8996 - val_accuracy: 0.8748 - val_loss: 0.2879 - val_pr_auc: 0.7419 - val_precision: 0.7502 - val_recall: 0.5577 - val_roc_auc: 0.9114 - learning_rate: 5.0000e-04
# Epoch 90/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8676 - loss: 0.3033 - pr_auc: 0.7234 - precision: 0.7273 - recall: 0.5532 - roc_auc: 0.9003 - val_accuracy: 0.8758 - val_loss: 0.2878 - val_pr_auc: 0.7421 - val_precision: 0.7483 - val_recall: 0.5687 - val_roc_auc: 0.9113 - learning_rate: 5.0000e-04
# Epoch 91/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8680 - loss: 0.3027 - pr_auc: 0.7248 - precision: 0.7283 - recall: 0.5548 - roc_auc: 0.9006 - val_accuracy: 0.8756 - val_loss: 0.2865 - val_pr_auc: 0.7440 - val_precision: 0.7488 - val_recall: 0.5658 - val_roc_auc: 0.9123 - learning_rate: 5.0000e-04
# Epoch 92/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8678 - loss: 0.3039 - pr_auc: 0.7228 - precision: 0.7283 - recall: 0.5532 - roc_auc: 0.8998 - val_accuracy: 0.8757 - val_loss: 0.2869 - val_pr_auc: 0.7428 - val_precision: 0.7506 - val_recall: 0.5641 - val_roc_auc: 0.9120 - learning_rate: 5.0000e-04
# Epoch 93/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8693 - loss: 0.3029 - pr_auc: 0.7257 - precision: 0.7324 - recall: 0.5579 - roc_auc: 0.9002 - val_accuracy: 0.8750 - val_loss: 0.2871 - val_pr_auc: 0.7425 - val_precision: 0.7523 - val_recall: 0.5566 - val_roc_auc: 0.9120 - learning_rate: 5.0000e-04
# Epoch 94/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8694 - loss: 0.3013 - pr_auc: 0.7275 - precision: 0.7324 - recall: 0.5589 - roc_auc: 0.9016 - val_accuracy: 0.8764 - val_loss: 0.2864 - val_pr_auc: 0.7437 - val_precision: 0.7502 - val_recall: 0.5698 - val_roc_auc: 0.9126 - learning_rate: 5.0000e-04
# Epoch 95/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8694 - loss: 0.3024 - pr_auc: 0.7256 - precision: 0.7320 - recall: 0.5592 - roc_auc: 0.9008 - val_accuracy: 0.8762 - val_loss: 0.2858 - val_pr_auc: 0.7448 - val_precision: 0.7545 - val_recall: 0.5618 - val_roc_auc: 0.9129 - learning_rate: 5.0000e-04
# Epoch 96/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8686 - loss: 0.3021 - pr_auc: 0.7270 - precision: 0.7298 - recall: 0.5572 - roc_auc: 0.9009 - val_accuracy: 0.8762 - val_loss: 0.2863 - val_pr_auc: 0.7438 - val_precision: 0.7461 - val_recall: 0.5749 - val_roc_auc: 0.9124 - learning_rate: 5.0000e-04
# Epoch 97/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8683 - loss: 0.3029 - pr_auc: 0.7254 - precision: 0.7296 - recall: 0.5551 - roc_auc: 0.9004 - val_accuracy: 0.8758 - val_loss: 0.2862 - val_pr_auc: 0.7438 - val_precision: 0.7486 - val_recall: 0.5683 - val_roc_auc: 0.9125 - learning_rate: 5.0000e-04
# Epoch 98/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8689 - loss: 0.3022 - pr_auc: 0.7265 - precision: 0.7297 - recall: 0.5595 - roc_auc: 0.9008 - val_accuracy: 0.8767 - val_loss: 0.2858 - val_pr_auc: 0.7447 - val_precision: 0.7548 - val_recall: 0.5652 - val_roc_auc: 0.9130 - learning_rate: 5.0000e-04
# Epoch 99/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8687 - loss: 0.3019 - pr_auc: 0.7267 - precision: 0.7295 - recall: 0.5582 - roc_auc: 0.9012 - val_accuracy: 0.8767 - val_loss: 0.2854 - val_pr_auc: 0.7452 - val_precision: 0.7507 - val_recall: 0.5717 - val_roc_auc: 0.9131 - learning_rate: 5.0000e-04
# Epoch 100/100
# 304/304 - 1s - 4ms/step - accuracy: 0.8690 - loss: 0.3021 - pr_auc: 0.7269 - precision: 0.7303 - recall: 0.5590 - roc_auc: 0.9009 - val_accuracy: 0.8767 - val_loss: 0.2857 - val_pr_auc: 0.7454 - val_precision: 0.7531 - val_recall: 0.5682 - val_roc_auc: 0.9128 - learning_rate: 5.0000e-04
# Accident classifier training complete.
# Features: 102
# Train rows: 310,881
# Validation rows: 67,599
# Test rows: 67,600
# Model: artifacts/models/mlp_accident_classifier_one_sided_selection_two_stage.keras
# Metrics: artifacts/reports/mlp_accident_classifier_one_sided_selection_two_stage_metrics.json
# History: artifacts/reports/mlp_accident_classifier_one_sided_selection_two_stage_history.csv
# Predictions: artifacts/predictions/mlp_accident_classifier_one_sided_selection_two_stage_test_predictions.csv
# Threshold metrics:
# {
#   "threshold": 0.5,
#   "accuracy": 0.875207100591716,
#   "precision": 0.7484245766049625,
#   "recall": 0.5637887553775405,
#   "f1": 0.6431170149758862,
#   "true_positive": 7601,
#   "false_positive": 2555,
#   "true_negative": 51563,
#   "false_negative": 5881
# }
# Top-K metrics:
# {
#   "1000": {
#     "k": 1000,
#     "hit_count": 944,
#     "precision_at_k": 0.944,
#     "recall_at_k": 0.070019284972556,
#     "f1_at_k": 0.13036873360033144
#   }
# }

# %%
model2_command = [
    sys.executable,
    str(PROJECT_ROOT / 'scripts' / 'train' / 'train_positive_risk_regressor.py'),
    '--train', str(TRAIN_PATH),
    '--val', str(VAL_PATH),
    '--test', str(TEST_PATH),
    '--model-path', str(MODEL2_MODEL_PATH),
    '--metrics-path', str(MODEL2_METRICS_PATH),
    '--history-path', str(MODEL2_HISTORY_PATH),
    '--predictions-path', str(MODEL2_PREDICTIONS_PATH),
    '--epochs', '100',
    '--batch-size', '1024',
    '--device', 'auto',
    '--verbose', '2',
]

print('모델 2 학습 명령:')
print(' '.join(model2_command))
print('주의: 모델 2 학습 스크립트는 내부에서 위험도 > 0 데이터만 필터링합니다.')

if RUN_TRAINING:
    subprocess.run(model2_command, check=True)
else:
    print('RUN_TRAINING=False 상태입니다. 실제 모델 2 학습은 실행하지 않았습니다.')
# Out:
# 모델 2 학습 명령:
# /home/huichan/SPARV/SilverWalk/.venv/bin/python /home/huichan/SPARV/SilverWalk/scripts/train/train_positive_risk_regressor.py --train /home/huichan/SPARV/SilverWalk/data/processed/original_train_train_preprocessed.csv --val /home/huichan/SPARV/SilverWalk/data/processed/original_train_val_preprocessed.csv --test /home/huichan/SPARV/SilverWalk/data/processed/original_train_test_preprocessed.csv --model-path /home/huichan/SPARV/SilverWalk/artifacts/models/mlp_positive_risk_regressor_one_sided_selection_two_stage.keras --metrics-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_positive_risk_regressor_one_sided_selection_two_stage_metrics.json --history-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_positive_risk_regressor_one_sided_selection_two_stage_history.csv --predictions-path /home/huichan/SPARV/SilverWalk/artifacts/predictions/mlp_positive_risk_regressor_one_sided_selection_two_stage_test_predictions.csv --epochs 100 --batch-size 1024 --device auto --verbose 2
# 주의: 모델 2 학습 스크립트는 내부에서 위험도 > 0 데이터만 필터링합니다.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780781361.946001   28440 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780781361.974642   28440 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780781362.732780   28440 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# W0000 00:00:1780781363.470369   28440 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/100
# 62/62 - 1s - 16ms/step - loss: 0.4123 - mae: 0.7697 - rmse: 1.0288 - val_loss: 0.3467 - val_mae: 0.6763 - val_rmse: 0.9615 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 - 0s - 5ms/step - loss: 0.3133 - mae: 0.6474 - rmse: 0.8735 - val_loss: 0.2807 - val_mae: 0.6020 - val_rmse: 0.8375 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 - 0s - 5ms/step - loss: 0.2928 - mae: 0.6212 - rmse: 0.8416 - val_loss: 0.2649 - val_mae: 0.5818 - val_rmse: 0.8010 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 - 0s - 5ms/step - loss: 0.2812 - mae: 0.6056 - rmse: 0.8221 - val_loss: 0.2575 - val_mae: 0.5727 - val_rmse: 0.7870 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 - 0s - 5ms/step - loss: 0.2741 - mae: 0.5968 - rmse: 0.8101 - val_loss: 0.2516 - val_mae: 0.5653 - val_rmse: 0.7747 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 - 0s - 5ms/step - loss: 0.2682 - mae: 0.5886 - rmse: 0.7994 - val_loss: 0.2461 - val_mae: 0.5573 - val_rmse: 0.7655 - learning_rate: 0.0010
# Epoch 7/100
# 62/62 - 0s - 5ms/step - loss: 0.2623 - mae: 0.5814 - rmse: 0.7888 - val_loss: 0.2416 - val_mae: 0.5512 - val_rmse: 0.7562 - learning_rate: 0.0010
# Epoch 8/100
# 62/62 - 0s - 5ms/step - loss: 0.2584 - mae: 0.5756 - rmse: 0.7828 - val_loss: 0.2373 - val_mae: 0.5447 - val_rmse: 0.7489 - learning_rate: 0.0010
# Epoch 9/100
# 62/62 - 0s - 5ms/step - loss: 0.2535 - mae: 0.5688 - rmse: 0.7735 - val_loss: 0.2324 - val_mae: 0.5389 - val_rmse: 0.7403 - learning_rate: 0.0010
# Epoch 10/100
# 62/62 - 0s - 5ms/step - loss: 0.2491 - mae: 0.5623 - rmse: 0.7664 - val_loss: 0.2286 - val_mae: 0.5328 - val_rmse: 0.7336 - learning_rate: 0.0010
# Epoch 11/100
# 62/62 - 0s - 5ms/step - loss: 0.2462 - mae: 0.5597 - rmse: 0.7602 - val_loss: 0.2259 - val_mae: 0.5296 - val_rmse: 0.7283 - learning_rate: 0.0010
# Epoch 12/100
# 62/62 - 0s - 5ms/step - loss: 0.2413 - mae: 0.5522 - rmse: 0.7514 - val_loss: 0.2203 - val_mae: 0.5205 - val_rmse: 0.7170 - learning_rate: 0.0010
# Epoch 13/100
# 62/62 - 0s - 5ms/step - loss: 0.2369 - mae: 0.5471 - rmse: 0.7427 - val_loss: 0.2176 - val_mae: 0.5172 - val_rmse: 0.7120 - learning_rate: 0.0010
# Epoch 14/100
# 62/62 - 0s - 5ms/step - loss: 0.2337 - mae: 0.5427 - rmse: 0.7366 - val_loss: 0.2144 - val_mae: 0.5124 - val_rmse: 0.7064 - learning_rate: 0.0010
# Epoch 15/100
# 62/62 - 0s - 5ms/step - loss: 0.2308 - mae: 0.5394 - rmse: 0.7310 - val_loss: 0.2112 - val_mae: 0.5089 - val_rmse: 0.7012 - learning_rate: 0.0010
# Epoch 16/100
# 62/62 - 0s - 5ms/step - loss: 0.2258 - mae: 0.5326 - rmse: 0.7213 - val_loss: 0.2080 - val_mae: 0.5034 - val_rmse: 0.6940 - learning_rate: 0.0010
# Epoch 17/100
# 62/62 - 0s - 5ms/step - loss: 0.2247 - mae: 0.5304 - rmse: 0.7196 - val_loss: 0.2048 - val_mae: 0.4983 - val_rmse: 0.6878 - learning_rate: 0.0010
# Epoch 18/100
# 62/62 - 0s - 6ms/step - loss: 0.2198 - mae: 0.5238 - rmse: 0.7106 - val_loss: 0.2035 - val_mae: 0.4964 - val_rmse: 0.6848 - learning_rate: 0.0010
# Epoch 19/100
# 62/62 - 0s - 5ms/step - loss: 0.2183 - mae: 0.5225 - rmse: 0.7079 - val_loss: 0.1998 - val_mae: 0.4929 - val_rmse: 0.6771 - learning_rate: 0.0010
# Epoch 20/100
# 62/62 - 0s - 5ms/step - loss: 0.2161 - mae: 0.5193 - rmse: 0.7022 - val_loss: 0.2005 - val_mae: 0.4926 - val_rmse: 0.6800 - learning_rate: 0.0010
# Epoch 21/100
# 62/62 - 0s - 5ms/step - loss: 0.2133 - mae: 0.5150 - rmse: 0.6977 - val_loss: 0.1962 - val_mae: 0.4867 - val_rmse: 0.6711 - learning_rate: 0.0010
# Epoch 22/100
# 62/62 - 0s - 5ms/step - loss: 0.2112 - mae: 0.5127 - rmse: 0.6937 - val_loss: 0.1973 - val_mae: 0.4870 - val_rmse: 0.6734 - learning_rate: 0.0010
# Epoch 23/100
# 62/62 - 0s - 5ms/step - loss: 0.2081 - mae: 0.5079 - rmse: 0.6876 - val_loss: 0.1917 - val_mae: 0.4801 - val_rmse: 0.6615 - learning_rate: 0.0010
# Epoch 24/100
# 62/62 - 0s - 5ms/step - loss: 0.2070 - mae: 0.5076 - rmse: 0.6853 - val_loss: 0.1912 - val_mae: 0.4802 - val_rmse: 0.6604 - learning_rate: 0.0010
# Epoch 25/100
# 62/62 - 0s - 5ms/step - loss: 0.2054 - mae: 0.5046 - rmse: 0.6824 - val_loss: 0.1897 - val_mae: 0.4773 - val_rmse: 0.6582 - learning_rate: 0.0010
# Epoch 26/100
# 62/62 - 0s - 5ms/step - loss: 0.2034 - mae: 0.5020 - rmse: 0.6779 - val_loss: 0.1870 - val_mae: 0.4747 - val_rmse: 0.6512 - learning_rate: 0.0010
# Epoch 27/100
# 62/62 - 0s - 5ms/step - loss: 0.2013 - mae: 0.4991 - rmse: 0.6743 - val_loss: 0.1847 - val_mae: 0.4712 - val_rmse: 0.6470 - learning_rate: 0.0010
# Epoch 28/100
# 62/62 - 0s - 4ms/step - loss: 0.1991 - mae: 0.4966 - rmse: 0.6696 - val_loss: 0.1852 - val_mae: 0.4712 - val_rmse: 0.6488 - learning_rate: 0.0010
# Epoch 29/100
# 62/62 - 0s - 5ms/step - loss: 0.1970 - mae: 0.4931 - rmse: 0.6661 - val_loss: 0.1813 - val_mae: 0.4663 - val_rmse: 0.6397 - learning_rate: 0.0010
# Epoch 30/100
# 62/62 - 0s - 5ms/step - loss: 0.1954 - mae: 0.4912 - rmse: 0.6623 - val_loss: 0.1807 - val_mae: 0.4656 - val_rmse: 0.6382 - learning_rate: 0.0010
# Epoch 31/100
# 62/62 - 0s - 5ms/step - loss: 0.1937 - mae: 0.4886 - rmse: 0.6590 - val_loss: 0.1797 - val_mae: 0.4640 - val_rmse: 0.6366 - learning_rate: 0.0010
# Epoch 32/100
# 62/62 - 0s - 5ms/step - loss: 0.1921 - mae: 0.4869 - rmse: 0.6554 - val_loss: 0.1792 - val_mae: 0.4624 - val_rmse: 0.6361 - learning_rate: 0.0010
# Epoch 33/100
# 62/62 - 0s - 5ms/step - loss: 0.1926 - mae: 0.4872 - rmse: 0.6565 - val_loss: 0.1794 - val_mae: 0.4618 - val_rmse: 0.6368 - learning_rate: 0.0010
# Epoch 34/100
# 62/62 - 0s - 5ms/step - loss: 0.1886 - mae: 0.4813 - rmse: 0.6494 - val_loss: 0.1745 - val_mae: 0.4561 - val_rmse: 0.6258 - learning_rate: 0.0010
# Epoch 35/100
# 62/62 - 0s - 4ms/step - loss: 0.1876 - mae: 0.4803 - rmse: 0.6468 - val_loss: 0.1774 - val_mae: 0.4598 - val_rmse: 0.6330 - learning_rate: 0.0010
# Epoch 36/100
# 62/62 - 0s - 4ms/step - loss: 0.1852 - mae: 0.4770 - rmse: 0.6422 - val_loss: 0.1750 - val_mae: 0.4562 - val_rmse: 0.6277 - learning_rate: 0.0010
# Epoch 37/100
# 62/62 - 0s - 5ms/step - loss: 0.1859 - mae: 0.4779 - rmse: 0.6430 - val_loss: 0.1730 - val_mae: 0.4550 - val_rmse: 0.6222 - learning_rate: 0.0010
# Epoch 38/100
# 62/62 - 0s - 5ms/step - loss: 0.1841 - mae: 0.4753 - rmse: 0.6402 - val_loss: 0.1715 - val_mae: 0.4510 - val_rmse: 0.6203 - learning_rate: 0.0010
# Epoch 39/100
# 62/62 - 0s - 5ms/step - loss: 0.1833 - mae: 0.4743 - rmse: 0.6380 - val_loss: 0.1696 - val_mae: 0.4497 - val_rmse: 0.6158 - learning_rate: 0.0010
# Epoch 40/100
# 62/62 - 0s - 5ms/step - loss: 0.1814 - mae: 0.4714 - rmse: 0.6346 - val_loss: 0.1670 - val_mae: 0.4463 - val_rmse: 0.6099 - learning_rate: 0.0010
# Epoch 41/100
# 62/62 - 0s - 5ms/step - loss: 0.1812 - mae: 0.4718 - rmse: 0.6335 - val_loss: 0.1662 - val_mae: 0.4440 - val_rmse: 0.6093 - learning_rate: 0.0010
# Epoch 42/100
# 62/62 - 0s - 4ms/step - loss: 0.1795 - mae: 0.4693 - rmse: 0.6304 - val_loss: 0.1667 - val_mae: 0.4449 - val_rmse: 0.6098 - learning_rate: 0.0010
# Epoch 43/100
# 62/62 - 0s - 5ms/step - loss: 0.1791 - mae: 0.4676 - rmse: 0.6300 - val_loss: 0.1652 - val_mae: 0.4428 - val_rmse: 0.6065 - learning_rate: 0.0010
# Epoch 44/100
# 62/62 - 0s - 5ms/step - loss: 0.1776 - mae: 0.4665 - rmse: 0.6260 - val_loss: 0.1630 - val_mae: 0.4395 - val_rmse: 0.6021 - learning_rate: 0.0010
# Epoch 45/100
# 62/62 - 0s - 5ms/step - loss: 0.1771 - mae: 0.4650 - rmse: 0.6258 - val_loss: 0.1618 - val_mae: 0.4369 - val_rmse: 0.6002 - learning_rate: 0.0010
# Epoch 46/100
# 62/62 - 0s - 4ms/step - loss: 0.1766 - mae: 0.4645 - rmse: 0.6244 - val_loss: 0.1639 - val_mae: 0.4404 - val_rmse: 0.6044 - learning_rate: 0.0010
# Epoch 47/100
# 62/62 - 0s - 5ms/step - loss: 0.1760 - mae: 0.4638 - rmse: 0.6236 - val_loss: 0.1628 - val_mae: 0.4370 - val_rmse: 0.6032 - learning_rate: 0.0010
# Epoch 48/100
# 62/62 - 0s - 4ms/step - loss: 0.1748 - mae: 0.4615 - rmse: 0.6209 - val_loss: 0.1645 - val_mae: 0.4407 - val_rmse: 0.6056 - learning_rate: 0.0010
# Epoch 49/100
# 62/62 - 0s - 4ms/step - loss: 0.1724 - mae: 0.4589 - rmse: 0.6159 - val_loss: 0.1618 - val_mae: 0.4366 - val_rmse: 0.6007 - learning_rate: 0.0010
# Epoch 50/100
# 62/62 - 0s - 5ms/step - loss: 0.1704 - mae: 0.4556 - rmse: 0.6113 - val_loss: 0.1586 - val_mae: 0.4311 - val_rmse: 0.5942 - learning_rate: 5.0000e-04
# Epoch 51/100
# 62/62 - 0s - 7ms/step - loss: 0.1697 - mae: 0.4547 - rmse: 0.6104 - val_loss: 0.1572 - val_mae: 0.4291 - val_rmse: 0.5912 - learning_rate: 5.0000e-04
# Epoch 52/100
# 62/62 - 0s - 6ms/step - loss: 0.1685 - mae: 0.4527 - rmse: 0.6083 - val_loss: 0.1577 - val_mae: 0.4303 - val_rmse: 0.5921 - learning_rate: 5.0000e-04
# Epoch 53/100
# 62/62 - 0s - 7ms/step - loss: 0.1668 - mae: 0.4500 - rmse: 0.6048 - val_loss: 0.1579 - val_mae: 0.4300 - val_rmse: 0.5928 - learning_rate: 5.0000e-04
# Epoch 54/100
# 62/62 - 0s - 7ms/step - loss: 0.1671 - mae: 0.4505 - rmse: 0.6054 - val_loss: 0.1557 - val_mae: 0.4270 - val_rmse: 0.5878 - learning_rate: 5.0000e-04
# Epoch 55/100
# 62/62 - 0s - 5ms/step - loss: 0.1673 - mae: 0.4505 - rmse: 0.6055 - val_loss: 0.1551 - val_mae: 0.4264 - val_rmse: 0.5865 - learning_rate: 5.0000e-04
# Epoch 56/100
# 62/62 - 0s - 5ms/step - loss: 0.1665 - mae: 0.4505 - rmse: 0.6038 - val_loss: 0.1542 - val_mae: 0.4247 - val_rmse: 0.5847 - learning_rate: 5.0000e-04
# Epoch 57/100
# 62/62 - 0s - 5ms/step - loss: 0.1660 - mae: 0.4496 - rmse: 0.6037 - val_loss: 0.1542 - val_mae: 0.4247 - val_rmse: 0.5850 - learning_rate: 5.0000e-04
# Epoch 58/100
# 62/62 - 0s - 5ms/step - loss: 0.1660 - mae: 0.4489 - rmse: 0.6029 - val_loss: 0.1542 - val_mae: 0.4240 - val_rmse: 0.5849 - learning_rate: 5.0000e-04
# Epoch 59/100
# 62/62 - 0s - 5ms/step - loss: 0.1649 - mae: 0.4471 - rmse: 0.6006 - val_loss: 0.1540 - val_mae: 0.4243 - val_rmse: 0.5844 - learning_rate: 5.0000e-04
# Epoch 60/100
# 62/62 - 0s - 5ms/step - loss: 0.1641 - mae: 0.4462 - rmse: 0.5989 - val_loss: 0.1530 - val_mae: 0.4231 - val_rmse: 0.5823 - learning_rate: 5.0000e-04
# Epoch 61/100
# 62/62 - 0s - 5ms/step - loss: 0.1638 - mae: 0.4456 - rmse: 0.5989 - val_loss: 0.1528 - val_mae: 0.4224 - val_rmse: 0.5820 - learning_rate: 5.0000e-04
# Epoch 62/100
# 62/62 - 0s - 5ms/step - loss: 0.1642 - mae: 0.4462 - rmse: 0.5995 - val_loss: 0.1530 - val_mae: 0.4219 - val_rmse: 0.5828 - learning_rate: 5.0000e-04
# Epoch 63/100
# 62/62 - 0s - 5ms/step - loss: 0.1633 - mae: 0.4446 - rmse: 0.5973 - val_loss: 0.1521 - val_mae: 0.4202 - val_rmse: 0.5803 - learning_rate: 5.0000e-04
# Epoch 64/100
# 62/62 - 0s - 4ms/step - loss: 0.1626 - mae: 0.4442 - rmse: 0.5956 - val_loss: 0.1524 - val_mae: 0.4213 - val_rmse: 0.5808 - learning_rate: 5.0000e-04
# Epoch 65/100
# 62/62 - 0s - 5ms/step - loss: 0.1628 - mae: 0.4444 - rmse: 0.5966 - val_loss: 0.1518 - val_mae: 0.4207 - val_rmse: 0.5795 - learning_rate: 5.0000e-04
# Epoch 66/100
# 62/62 - 0s - 4ms/step - loss: 0.1623 - mae: 0.4431 - rmse: 0.5957 - val_loss: 0.1526 - val_mae: 0.4211 - val_rmse: 0.5812 - learning_rate: 5.0000e-04
# Epoch 67/100
# 62/62 - 0s - 5ms/step - loss: 0.1620 - mae: 0.4426 - rmse: 0.5949 - val_loss: 0.1517 - val_mae: 0.4199 - val_rmse: 0.5797 - learning_rate: 5.0000e-04
# Epoch 68/100
# 62/62 - 0s - 5ms/step - loss: 0.1624 - mae: 0.4432 - rmse: 0.5957 - val_loss: 0.1501 - val_mae: 0.4177 - val_rmse: 0.5764 - learning_rate: 5.0000e-04
# Epoch 69/100
# 62/62 - 0s - 5ms/step - loss: 0.1606 - mae: 0.4415 - rmse: 0.5920 - val_loss: 0.1502 - val_mae: 0.4177 - val_rmse: 0.5768 - learning_rate: 5.0000e-04
# Epoch 70/100
# 62/62 - 0s - 5ms/step - loss: 0.1599 - mae: 0.4393 - rmse: 0.5908 - val_loss: 0.1494 - val_mae: 0.4168 - val_rmse: 0.5747 - learning_rate: 5.0000e-04
# Epoch 71/100
# 62/62 - 0s - 5ms/step - loss: 0.1597 - mae: 0.4401 - rmse: 0.5902 - val_loss: 0.1491 - val_mae: 0.4166 - val_rmse: 0.5738 - learning_rate: 5.0000e-04
# Epoch 72/100
# 62/62 - 0s - 5ms/step - loss: 0.1612 - mae: 0.4419 - rmse: 0.5929 - val_loss: 0.1505 - val_mae: 0.4187 - val_rmse: 0.5770 - learning_rate: 5.0000e-04
# Epoch 73/100
# 62/62 - 0s - 4ms/step - loss: 0.1603 - mae: 0.4401 - rmse: 0.5914 - val_loss: 0.1501 - val_mae: 0.4181 - val_rmse: 0.5762 - learning_rate: 5.0000e-04
# Epoch 74/100
# 62/62 - 0s - 5ms/step - loss: 0.1610 - mae: 0.4418 - rmse: 0.5931 - val_loss: 0.1511 - val_mae: 0.4191 - val_rmse: 0.5783 - learning_rate: 5.0000e-04
# Epoch 75/100
# 62/62 - 0s - 5ms/step - loss: 0.1595 - mae: 0.4396 - rmse: 0.5891 - val_loss: 0.1491 - val_mae: 0.4166 - val_rmse: 0.5739 - learning_rate: 5.0000e-04
# Epoch 76/100
# 62/62 - 0s - 5ms/step - loss: 0.1573 - mae: 0.4353 - rmse: 0.5853 - val_loss: 0.1472 - val_mae: 0.4142 - val_rmse: 0.5700 - learning_rate: 2.5000e-04
# Epoch 77/100
# 62/62 - 0s - 5ms/step - loss: 0.1569 - mae: 0.4354 - rmse: 0.5839 - val_loss: 0.1473 - val_mae: 0.4135 - val_rmse: 0.5701 - learning_rate: 2.5000e-04
# Epoch 78/100
# 62/62 - 0s - 5ms/step - loss: 0.1567 - mae: 0.4353 - rmse: 0.5838 - val_loss: 0.1463 - val_mae: 0.4120 - val_rmse: 0.5680 - learning_rate: 2.5000e-04
# Epoch 79/100
# 62/62 - 0s - 5ms/step - loss: 0.1563 - mae: 0.4350 - rmse: 0.5823 - val_loss: 0.1468 - val_mae: 0.4122 - val_rmse: 0.5691 - learning_rate: 2.5000e-04
# Epoch 80/100
# 62/62 - 0s - 5ms/step - loss: 0.1573 - mae: 0.4361 - rmse: 0.5848 - val_loss: 0.1464 - val_mae: 0.4125 - val_rmse: 0.5680 - learning_rate: 2.5000e-04
# Epoch 81/100
# 62/62 - 0s - 4ms/step - loss: 0.1559 - mae: 0.4342 - rmse: 0.5818 - val_loss: 0.1465 - val_mae: 0.4121 - val_rmse: 0.5684 - learning_rate: 2.5000e-04
# Epoch 82/100
# 62/62 - 0s - 5ms/step - loss: 0.1557 - mae: 0.4338 - rmse: 0.5811 - val_loss: 0.1468 - val_mae: 0.4122 - val_rmse: 0.5690 - learning_rate: 2.5000e-04
# Epoch 83/100
# 62/62 - 0s - 5ms/step - loss: 0.1555 - mae: 0.4329 - rmse: 0.5809 - val_loss: 0.1455 - val_mae: 0.4105 - val_rmse: 0.5662 - learning_rate: 1.2500e-04
# Epoch 84/100
# 62/62 - 0s - 5ms/step - loss: 0.1550 - mae: 0.4330 - rmse: 0.5797 - val_loss: 0.1453 - val_mae: 0.4102 - val_rmse: 0.5657 - learning_rate: 1.2500e-04
# Epoch 85/100
# 62/62 - 0s - 5ms/step - loss: 0.1551 - mae: 0.4329 - rmse: 0.5806 - val_loss: 0.1453 - val_mae: 0.4102 - val_rmse: 0.5657 - learning_rate: 1.2500e-04
# Epoch 86/100
# 62/62 - 0s - 5ms/step - loss: 0.1547 - mae: 0.4321 - rmse: 0.5799 - val_loss: 0.1448 - val_mae: 0.4093 - val_rmse: 0.5648 - learning_rate: 1.2500e-04
# Epoch 87/100
# 62/62 - 0s - 5ms/step - loss: 0.1539 - mae: 0.4304 - rmse: 0.5780 - val_loss: 0.1447 - val_mae: 0.4094 - val_rmse: 0.5644 - learning_rate: 1.2500e-04
# Epoch 88/100
# 62/62 - 0s - 5ms/step - loss: 0.1544 - mae: 0.4314 - rmse: 0.5785 - val_loss: 0.1450 - val_mae: 0.4096 - val_rmse: 0.5651 - learning_rate: 1.2500e-04
# Epoch 89/100
# 62/62 - 0s - 5ms/step - loss: 0.1535 - mae: 0.4310 - rmse: 0.5767 - val_loss: 0.1450 - val_mae: 0.4096 - val_rmse: 0.5652 - learning_rate: 1.2500e-04
# Epoch 90/100
# 62/62 - 0s - 5ms/step - loss: 0.1543 - mae: 0.4314 - rmse: 0.5783 - val_loss: 0.1452 - val_mae: 0.4099 - val_rmse: 0.5656 - learning_rate: 1.2500e-04
# Epoch 91/100
# 62/62 - 0s - 5ms/step - loss: 0.1552 - mae: 0.4328 - rmse: 0.5802 - val_loss: 0.1452 - val_mae: 0.4100 - val_rmse: 0.5658 - learning_rate: 1.2500e-04
# Epoch 92/100
# 62/62 - 0s - 5ms/step - loss: 0.1530 - mae: 0.4297 - rmse: 0.5756 - val_loss: 0.1447 - val_mae: 0.4092 - val_rmse: 0.5645 - learning_rate: 6.2500e-05
# Epoch 93/100
# 62/62 - 0s - 4ms/step - loss: 0.1531 - mae: 0.4297 - rmse: 0.5757 - val_loss: 0.1448 - val_mae: 0.4092 - val_rmse: 0.5647 - learning_rate: 6.2500e-05
# Epoch 94/100
# 62/62 - 0s - 5ms/step - loss: 0.1537 - mae: 0.4309 - rmse: 0.5769 - val_loss: 0.1446 - val_mae: 0.4089 - val_rmse: 0.5644 - learning_rate: 6.2500e-05
# Epoch 95/100
# 62/62 - 0s - 5ms/step - loss: 0.1528 - mae: 0.4290 - rmse: 0.5756 - val_loss: 0.1445 - val_mae: 0.4087 - val_rmse: 0.5640 - learning_rate: 6.2500e-05
# Epoch 96/100
# 62/62 - 0s - 5ms/step - loss: 0.1536 - mae: 0.4305 - rmse: 0.5773 - val_loss: 0.1449 - val_mae: 0.4093 - val_rmse: 0.5650 - learning_rate: 6.2500e-05
# Epoch 97/100
# 62/62 - 0s - 5ms/step - loss: 0.1525 - mae: 0.4290 - rmse: 0.5747 - val_loss: 0.1446 - val_mae: 0.4089 - val_rmse: 0.5643 - learning_rate: 6.2500e-05
# Epoch 98/100
# 62/62 - 0s - 4ms/step - loss: 0.1536 - mae: 0.4299 - rmse: 0.5773 - val_loss: 0.1446 - val_mae: 0.4090 - val_rmse: 0.5644 - learning_rate: 6.2500e-05
# Epoch 99/100
# 62/62 - 0s - 5ms/step - loss: 0.1533 - mae: 0.4300 - rmse: 0.5772 - val_loss: 0.1446 - val_mae: 0.4088 - val_rmse: 0.5642 - learning_rate: 6.2500e-05
# Epoch 100/100
# 62/62 - 0s - 5ms/step - loss: 0.1539 - mae: 0.4316 - rmse: 0.5775 - val_loss: 0.1444 - val_mae: 0.4087 - val_rmse: 0.5639 - learning_rate: 3.1250e-05
# Positive risk regressor training complete.
# Features: 102
# Raw train rows: 315,464 -> positive: 62,913
# Raw validation rows: 67,599 -> positive: 13,481
# Raw test rows: 67,600 -> positive: 13,482
# Model: artifacts/models/mlp_positive_risk_regressor_one_sided_selection_two_stage.keras
# Metrics: artifacts/reports/mlp_positive_risk_regressor_one_sided_selection_two_stage_metrics.json
# History: artifacts/reports/mlp_positive_risk_regressor_one_sided_selection_two_stage_history.csv
# Predictions: artifacts/predictions/mlp_positive_risk_regressor_one_sided_selection_two_stage_test_predictions.csv
# Test risk-scale metrics:
# {
#   "mae": 2.0521783696501275,
#   "rmse": 6.290265559463401,
#   "r2": 0.535287392690655
# }

# %% [markdown]
# ## 결과 지표 표 위치
#
# 실험을 실행한 뒤 아래 지표만 `docs/기법별_성능평가.md`의 평가표에 작성한다.
#
# | 모델 | PR-AUC | Recall@Top10% | Precision@Top10% | MAE | RMSE |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | 실험명 | 실행 후 입력 | 실행 후 입력 | 실행 후 입력 | 실행 후 입력 | 실행 후 입력 |

# %%
def top_percent_binary_metrics(predictions: pd.DataFrame, score_column: str, target_column: str, percent: float = 0.10) -> dict[str, float]:
    """예측 점수 상위 percent 구간의 precision/recall을 계산한다."""
    if predictions.empty:
        return {'precision_top10pct': math.nan, 'recall_top10pct': math.nan}

    k = max(1, math.ceil(len(predictions) * percent))
    ranked = predictions.sort_values(score_column, ascending=False).head(k)
    actual_positive = predictions[target_column].astype(int)
    top_positive = ranked[target_column].astype(int)

    precision = float(top_positive.sum() / k)
    recall = float(top_positive.sum() / actual_positive.sum()) if actual_positive.sum() else math.nan
    return {'precision_top10pct': precision, 'recall_top10pct': recall}


def rmse(y_true: pd.Series, y_pred: pd.Series) -> float:
    """scikit-learn 버전 차이를 피하기 위해 RMSE를 직접 계산한다."""
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))


if MODEL1_PREDICTIONS_PATH.exists() and MODEL2_PREDICTIONS_PATH.exists():
    model1_predictions = pd.read_csv(MODEL1_PREDICTIONS_PATH)
    model2_predictions = pd.read_csv(MODEL2_PREDICTIONS_PATH)

    model1_summary = top_percent_binary_metrics(
        model1_predictions,
        score_column='사고발생확률',
        target_column='사고발생',
        percent=0.10,
    )
    model1_summary['pr_auc'] = float(
        average_precision_score(model1_predictions['사고발생'], model1_predictions['사고발생확률'])
    )

    model2_summary = {
        'mae': float(mean_absolute_error(model2_predictions['위험도'], model2_predictions['pred_위험도'])),
        'rmse': rmse(model2_predictions['위험도'], model2_predictions['pred_위험도']),
    }

    summary = pd.DataFrame([
        {
            '모델': EXPERIMENT_NAME,
            'PR-AUC': model1_summary['pr_auc'],
            'Recall@Top10%': model1_summary['recall_top10pct'],
            'Precision@Top10%': model1_summary['precision_top10pct'],
            'MAE': model2_summary['mae'],
            'RMSE': model2_summary['rmse'],
        }
    ])

    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    summary.to_csv(EXPERIMENT_RESULT_PATH, index=False)
    display(summary)
    print(f'실험 요약 저장: {EXPERIMENT_RESULT_PATH.relative_to(PROJECT_ROOT)}')
    print(f'문서 평가표 위치: {DOCS_TABLE_PATH.relative_to(PROJECT_ROOT)}')
else:
    print('아직 모델 예측 파일이 없습니다. RUN_SAMPLING=True, RUN_TRAINING=True로 학습을 마친 뒤 다시 실행하십시오.')
    print(f'필요 파일: {MODEL1_PREDICTIONS_PATH.relative_to(PROJECT_ROOT)}')
    print(f'필요 파일: {MODEL2_PREDICTIONS_PATH.relative_to(PROJECT_ROOT)}')
# Out:
#                           모델    PR-AUC  Recall@Top10%  Precision@Top10%  \
# 0  Undersampling OSS + 모델 2개  0.740009       0.411215          0.820118
#
#         MAE      RMSE
# 0  2.052178  6.290266
# 실험 요약 저장: artifacts/experiments/one_sided_selection_two_stage/one_sided_selection_two_stage_summary.csv
# 문서 평가표 위치: docs/기법별_성능평가.md

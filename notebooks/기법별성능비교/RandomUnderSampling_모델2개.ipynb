# %% [markdown]
# # Random Under Sampling 1:1 + 모델 2개 성능 비교
#
# 이 notebook은 `docs/기법별_성능평가.md`의 평가 계획에 맞춰 `Undersampling Random under Sampling (비율 1대1) + 모델 2개` 실험을 준비하는 템플릿입니다.

# %% [markdown]
# ## 목적
#
# 사고 미발생 샘플을 무작위로 줄여 사고발생=0:1 비율을 1:1로 맞췄을 때 모델 1의 탐지 성능 변화를 확인한다.
#
# Random Under Sampling은 다수 클래스 정보를 버리므로 PR-AUC와 Top10% 지표가 개선되는지 반드시 확인한다.

# %% [markdown]
# ## 필요한 입력 파일
#
# - `data/processed/original_train_train_preprocessed.csv`
# - `data/processed/original_train_val_preprocessed.csv`
# - `data/processed/original_train_test_preprocessed.csv`
# - `artifacts/preprocessors/original_train_preprocess_config.json`
#
# ## 실행 절차
#
# 1. 입력 파일과 feature 목록을 확인한다.
# 2. 모델 1 학습용 train split에만 imbalanced-learn sampling을 적용한다.
# 3. sampling된 train CSV를 저장한다.
# 4. 모델 1은 sampling된 train CSV로 학습한다.
# 5. 모델 2는 sampling을 적용하지 않고, 기존 스크립트가 `위험도 > 0` 데이터만 필터링하여 학습한다.
# 6. 결과 지표를 계산하고 `docs/기법별_성능평가.md` 평가표에 옮겨 적는다.
#
# ## 모델 2 주의사항
#
# 모델 2 회귀모델은 항상 `위험도 > 0` 데이터만 사용한다. Sampling 기법은 모델 1의 `사고발생` 분류 문제에만 적용한다.

# %%
from __future__ import annotations

import json
import math
import subprocess
import sys
from pathlib import Path

import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.metrics import average_precision_score, mean_absolute_error, mean_squared_error

from imblearn.under_sampling import RandomUnderSampler

PROJECT_ROOT = next(
    candidate for candidate in [Path.cwd(), *Path.cwd().parents]
    if (candidate / 'src').exists()
)

DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
TRAIN_PATH = DATA_DIR / 'original_train_train_preprocessed.csv'
VAL_PATH = DATA_DIR / 'original_train_val_preprocessed.csv'
TEST_PATH = DATA_DIR / 'original_train_test_preprocessed.csv'
PREPROCESS_CONFIG_PATH = PROJECT_ROOT / 'artifacts' / 'preprocessors' / 'original_train_preprocess_config.json'

EXPERIMENT_NAME = 'Undersampling Random under Sampling (비율 1대1) + 모델 2개'
EXPERIMENT_SLUG = 'random_under_sampling_two_stage'
RANDOM_STATE = 42
ROW_LIMIT = None  # None이면 전체 train 데이터를 사용한다.
RUN_SAMPLING = True  # 실제 sampling CSV를 만들려면 True로 변경한다.
RUN_TRAINING = True  # 실제 모델 학습까지 실행하려면 True로 변경한다.

OUTPUT_DIR = PROJECT_ROOT / 'artifacts' / 'experiments' / EXPERIMENT_SLUG
SAMPLED_INPUT_DIR = PROJECT_ROOT / 'artifacts' / 'experiments' / 'sampling_inputs'
SAMPLED_TRAIN_PATH = SAMPLED_INPUT_DIR / f'{EXPERIMENT_SLUG}_model1_train_preprocessed.csv'

MODEL1_MODEL_PATH = PROJECT_ROOT / 'artifacts' / 'models' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}.keras'
MODEL1_METRICS_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}_metrics.json'
MODEL1_HISTORY_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}_history.csv'
MODEL1_PREDICTIONS_PATH = PROJECT_ROOT / 'artifacts' / 'predictions' / f'mlp_accident_classifier_{EXPERIMENT_SLUG}_test_predictions.csv'

MODEL2_MODEL_PATH = PROJECT_ROOT / 'artifacts' / 'models' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}.keras'
MODEL2_METRICS_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}_metrics.json'
MODEL2_HISTORY_PATH = PROJECT_ROOT / 'artifacts' / 'reports' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}_history.csv'
MODEL2_PREDICTIONS_PATH = PROJECT_ROOT / 'artifacts' / 'predictions' / f'mlp_positive_risk_regressor_{EXPERIMENT_SLUG}_test_predictions.csv'

EXPERIMENT_RESULT_PATH = OUTPUT_DIR / f'{EXPERIMENT_SLUG}_summary.csv'
DOCS_TABLE_PATH = PROJECT_ROOT / 'docs' / '기법별_성능평가.md'

# %%
required_paths = {
    'train': TRAIN_PATH,
    'val': VAL_PATH,
    'test': TEST_PATH,
    'preprocess_config': PREPROCESS_CONFIG_PATH,
    'docs_table': DOCS_TABLE_PATH,
}

path_status = pd.DataFrame(
    [{'name': name, 'path': str(path.relative_to(PROJECT_ROOT)), 'exists': path.exists()} for name, path in required_paths.items()]
)
display(path_status)

missing = path_status.loc[~path_status['exists'], 'path'].tolist()
if missing:
    raise FileNotFoundError(f'필요한 파일이 없습니다: {missing}')

with PREPROCESS_CONFIG_PATH.open('r', encoding='utf-8') as file:
    preprocess_config = json.load(file)

feature_columns = preprocess_config['feature_columns']
print(f'feature 수: {len(feature_columns):,}')
# Out:
#                 name                                               path  \
# 0              train  data/processed/original_train_train_preprocess...
# 1                val  data/processed/original_train_val_preprocessed...
# 2               test  data/processed/original_train_test_preprocesse...
# 3  preprocess_config  artifacts/preprocessors/original_train_preproc...
# 4         docs_table                                   docs/기법별_성능평가.md
#
#    exists
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# feature 수: 102

# %%
def accident_target(frame: pd.DataFrame) -> pd.Series:
    """위험도 값을 모델 1의 사고발생 이진 라벨로 변환한다."""
    return (frame['위험도'] > 0).astype(int)


train_frame = pd.read_csv(TRAIN_PATH, nrows=ROW_LIMIT)
X_train = train_frame[feature_columns]
y_train = accident_target(train_frame)

print('sampling 실행 전 클래스 분포')
display(y_train.value_counts().rename(index={0: '사고발생=0', 1: '사고발생=1'}).to_frame('count'))

sampler = RandomUnderSampler(sampling_strategy=1.0, random_state=RANDOM_STATE)
print(sampler)

if RUN_SAMPLING:
    X_resampled, y_resampled = sampler.fit_resample(X_train, y_train)
    sampled_train = pd.DataFrame(X_resampled, columns=feature_columns)

    # 모델 1 학습 스크립트는 위험도 > 0 여부만 사용하므로, sampling 후 라벨 복원을 위해 위험도 컬럼을 만든다.
    sampled_train['위험도'] = np.where(np.asarray(y_resampled) == 1, 1.0, 0.0)

    SAMPLED_INPUT_DIR.mkdir(parents=True, exist_ok=True)
    sampled_train.to_csv(SAMPLED_TRAIN_PATH, index=False)

    print('sampling 실행 후 클래스 분포')
    display(pd.Series(y_resampled).value_counts().rename(index={0: '사고발생=0', 1: '사고발생=1'}).to_frame('count'))
    print(f'sampled train 저장: {SAMPLED_TRAIN_PATH.relative_to(PROJECT_ROOT)}')
else:
    print('RUN_SAMPLING=False 상태입니다. 실제 sampling CSV 생성은 실행하지 않았습니다.')
    print('실행하려면 위 설정 셀에서 RUN_SAMPLING=True로 변경하십시오.')
# Out:
# sampling 실행 전 클래스 분포
#          count
# 위험도
# 사고발생=0  252551
# 사고발생=1   62913
# RandomUnderSampler(random_state=42, sampling_strategy=1.0)
# /tmp/ipykernel_14185/1530571193.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sampled_train['위험도'] = np.where(np.asarray(y_resampled) == 1, 1.0, 0.0)
# sampling 실행 후 클래스 분포
#         count
# 위험도
# 사고발생=0  62913
# 사고발생=1  62913
# sampled train 저장: artifacts/experiments/sampling_inputs/random_under_sampling_two_stage_model1_train_preprocessed.csv

# %%
model1_command = [
    sys.executable,
    str(PROJECT_ROOT / 'scripts' / 'train' / 'train_accident_classifier.py'),
    '--train', str(SAMPLED_TRAIN_PATH),
    '--val', str(VAL_PATH),
    '--test', str(TEST_PATH),
    '--model-path', str(MODEL1_MODEL_PATH),
    '--metrics-path', str(MODEL1_METRICS_PATH),
    '--history-path', str(MODEL1_HISTORY_PATH),
    '--predictions-path', str(MODEL1_PREDICTIONS_PATH),
    '--epochs', '100',
    '--batch-size', '1024',
    '--device', 'auto',
    '--verbose', '2',
    '--top-k', '1000',
]

print('모델 1 학습 명령:')
print(' '.join(model1_command))

if RUN_TRAINING:
    if not SAMPLED_TRAIN_PATH.exists():
        raise FileNotFoundError('모델 1 학습 전 RUN_SAMPLING=True로 sampling train CSV를 먼저 생성해야 합니다.')
    subprocess.run(model1_command, check=True)
else:
    print('RUN_TRAINING=False 상태입니다. 실제 모델 1 학습은 실행하지 않았습니다.')
# Out:
# 모델 1 학습 명령:
# /home/huichan/SPARV/SilverWalk/.venv/bin/python /home/huichan/SPARV/SilverWalk/scripts/train/train_accident_classifier.py --train /home/huichan/SPARV/SilverWalk/artifacts/experiments/sampling_inputs/random_under_sampling_two_stage_model1_train_preprocessed.csv --val /home/huichan/SPARV/SilverWalk/data/processed/original_train_val_preprocessed.csv --test /home/huichan/SPARV/SilverWalk/data/processed/original_train_test_preprocessed.csv --model-path /home/huichan/SPARV/SilverWalk/artifacts/models/mlp_accident_classifier_random_under_sampling_two_stage.keras --metrics-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_accident_classifier_random_under_sampling_two_stage_metrics.json --history-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_accident_classifier_random_under_sampling_two_stage_history.csv --predictions-path /home/huichan/SPARV/SilverWalk/artifacts/predictions/mlp_accident_classifier_random_under_sampling_two_stage_test_predictions.csv --epochs 100 --batch-size 1024 --device auto --verbose 2 --top-k 1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780780850.494796   14255 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780780850.532879   14255 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780780851.336183   14255 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# W0000 00:00:1780780852.091522   14255 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/100
# 123/123 - 2s - 13ms/step - accuracy: 0.6744 - loss: 0.6042 - pr_auc: 0.7275 - precision: 0.6796 - recall: 0.6598 - roc_auc: 0.7381 - val_accuracy: 0.6561 - val_loss: 0.6206 - val_pr_auc: 0.4789 - val_precision: 0.3408 - val_recall: 0.7755 - val_roc_auc: 0.7742 - learning_rate: 0.0010
# Epoch 2/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7037 - loss: 0.5717 - pr_auc: 0.7629 - precision: 0.7074 - recall: 0.6948 - roc_auc: 0.7723 - val_accuracy: 0.7082 - val_loss: 0.5711 - val_pr_auc: 0.5020 - val_precision: 0.3796 - val_recall: 0.7298 - val_roc_auc: 0.7880 - learning_rate: 0.0010
# Epoch 3/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7119 - loss: 0.5617 - pr_auc: 0.7721 - precision: 0.7139 - recall: 0.7070 - roc_auc: 0.7824 - val_accuracy: 0.7279 - val_loss: 0.5450 - val_pr_auc: 0.5146 - val_precision: 0.3987 - val_recall: 0.7163 - val_roc_auc: 0.7974 - learning_rate: 0.0010
# Epoch 4/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7185 - loss: 0.5525 - pr_auc: 0.7817 - precision: 0.7194 - recall: 0.7165 - roc_auc: 0.7912 - val_accuracy: 0.7361 - val_loss: 0.5323 - val_pr_auc: 0.5238 - val_precision: 0.4080 - val_recall: 0.7174 - val_roc_auc: 0.8040 - learning_rate: 0.0010
# Epoch 5/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7235 - loss: 0.5449 - pr_auc: 0.7879 - precision: 0.7233 - recall: 0.7240 - roc_auc: 0.7983 - val_accuracy: 0.7399 - val_loss: 0.5222 - val_pr_auc: 0.5348 - val_precision: 0.4135 - val_recall: 0.7277 - val_roc_auc: 0.8111 - learning_rate: 0.0010
# Epoch 6/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7300 - loss: 0.5382 - pr_auc: 0.7938 - precision: 0.7279 - recall: 0.7346 - roc_auc: 0.8041 - val_accuracy: 0.7447 - val_loss: 0.5139 - val_pr_auc: 0.5433 - val_precision: 0.4197 - val_recall: 0.7330 - val_roc_auc: 0.8165 - learning_rate: 0.0010
# Epoch 7/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7337 - loss: 0.5319 - pr_auc: 0.7993 - precision: 0.7315 - recall: 0.7385 - roc_auc: 0.8096 - val_accuracy: 0.7525 - val_loss: 0.5019 - val_pr_auc: 0.5498 - val_precision: 0.4290 - val_recall: 0.7288 - val_roc_auc: 0.8214 - learning_rate: 0.0010
# Epoch 8/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7375 - loss: 0.5264 - pr_auc: 0.8034 - precision: 0.7342 - recall: 0.7445 - roc_auc: 0.8143 - val_accuracy: 0.7571 - val_loss: 0.4949 - val_pr_auc: 0.5570 - val_precision: 0.4351 - val_recall: 0.7318 - val_roc_auc: 0.8261 - learning_rate: 0.0010
# Epoch 9/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7406 - loss: 0.5206 - pr_auc: 0.8075 - precision: 0.7356 - recall: 0.7512 - roc_auc: 0.8191 - val_accuracy: 0.7555 - val_loss: 0.4938 - val_pr_auc: 0.5639 - val_precision: 0.4341 - val_recall: 0.7436 - val_roc_auc: 0.8302 - learning_rate: 0.0010
# Epoch 10/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7453 - loss: 0.5144 - pr_auc: 0.8127 - precision: 0.7399 - recall: 0.7566 - roc_auc: 0.8241 - val_accuracy: 0.7577 - val_loss: 0.4887 - val_pr_auc: 0.5690 - val_precision: 0.4371 - val_recall: 0.7479 - val_roc_auc: 0.8343 - learning_rate: 0.0010
# Epoch 11/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7494 - loss: 0.5098 - pr_auc: 0.8161 - precision: 0.7438 - recall: 0.7606 - roc_auc: 0.8278 - val_accuracy: 0.7596 - val_loss: 0.4827 - val_pr_auc: 0.5736 - val_precision: 0.4398 - val_recall: 0.7517 - val_roc_auc: 0.8372 - learning_rate: 0.0010
# Epoch 12/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7523 - loss: 0.5058 - pr_auc: 0.8186 - precision: 0.7465 - recall: 0.7639 - roc_auc: 0.8307 - val_accuracy: 0.7616 - val_loss: 0.4802 - val_pr_auc: 0.5800 - val_precision: 0.4431 - val_recall: 0.7607 - val_roc_auc: 0.8416 - learning_rate: 0.0010
# Epoch 13/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7538 - loss: 0.5020 - pr_auc: 0.8228 - precision: 0.7476 - recall: 0.7663 - roc_auc: 0.8335 - val_accuracy: 0.7638 - val_loss: 0.4789 - val_pr_auc: 0.5836 - val_precision: 0.4462 - val_recall: 0.7641 - val_roc_auc: 0.8447 - learning_rate: 0.0010
# Epoch 14/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7568 - loss: 0.4990 - pr_auc: 0.8244 - precision: 0.7495 - recall: 0.7715 - roc_auc: 0.8357 - val_accuracy: 0.7585 - val_loss: 0.4831 - val_pr_auc: 0.5890 - val_precision: 0.4405 - val_recall: 0.7821 - val_roc_auc: 0.8476 - learning_rate: 0.0010
# Epoch 15/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7589 - loss: 0.4951 - pr_auc: 0.8253 - precision: 0.7513 - recall: 0.7742 - roc_auc: 0.8386 - val_accuracy: 0.7641 - val_loss: 0.4731 - val_pr_auc: 0.5925 - val_precision: 0.4472 - val_recall: 0.7749 - val_roc_auc: 0.8497 - learning_rate: 0.0010
# Epoch 16/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7607 - loss: 0.4904 - pr_auc: 0.8298 - precision: 0.7528 - recall: 0.7764 - roc_auc: 0.8421 - val_accuracy: 0.7660 - val_loss: 0.4724 - val_pr_auc: 0.5958 - val_precision: 0.4500 - val_recall: 0.7809 - val_roc_auc: 0.8523 - learning_rate: 0.0010
# Epoch 17/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7632 - loss: 0.4891 - pr_auc: 0.8315 - precision: 0.7553 - recall: 0.7787 - roc_auc: 0.8431 - val_accuracy: 0.7704 - val_loss: 0.4664 - val_pr_auc: 0.5982 - val_precision: 0.4557 - val_recall: 0.7776 - val_roc_auc: 0.8545 - learning_rate: 0.0010
# Epoch 18/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7658 - loss: 0.4849 - pr_auc: 0.8329 - precision: 0.7570 - recall: 0.7829 - roc_auc: 0.8462 - val_accuracy: 0.7677 - val_loss: 0.4697 - val_pr_auc: 0.6002 - val_precision: 0.4527 - val_recall: 0.7892 - val_roc_auc: 0.8559 - learning_rate: 0.0010
# Epoch 19/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7668 - loss: 0.4823 - pr_auc: 0.8357 - precision: 0.7578 - recall: 0.7843 - roc_auc: 0.8479 - val_accuracy: 0.7682 - val_loss: 0.4671 - val_pr_auc: 0.6013 - val_precision: 0.4533 - val_recall: 0.7881 - val_roc_auc: 0.8571 - learning_rate: 0.0010
# Epoch 20/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7688 - loss: 0.4798 - pr_auc: 0.8375 - precision: 0.7595 - recall: 0.7867 - roc_auc: 0.8495 - val_accuracy: 0.7709 - val_loss: 0.4639 - val_pr_auc: 0.6067 - val_precision: 0.4569 - val_recall: 0.7895 - val_roc_auc: 0.8601 - learning_rate: 0.0010
# Epoch 21/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7723 - loss: 0.4760 - pr_auc: 0.8402 - precision: 0.7624 - recall: 0.7912 - roc_auc: 0.8524 - val_accuracy: 0.7706 - val_loss: 0.4629 - val_pr_auc: 0.6091 - val_precision: 0.4567 - val_recall: 0.7933 - val_roc_auc: 0.8610 - learning_rate: 0.0010
# Epoch 22/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7726 - loss: 0.4742 - pr_auc: 0.8419 - precision: 0.7638 - recall: 0.7892 - roc_auc: 0.8536 - val_accuracy: 0.7748 - val_loss: 0.4570 - val_pr_auc: 0.6125 - val_precision: 0.4623 - val_recall: 0.7933 - val_roc_auc: 0.8629 - learning_rate: 0.0010
# Epoch 23/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7746 - loss: 0.4718 - pr_auc: 0.8435 - precision: 0.7655 - recall: 0.7917 - roc_auc: 0.8554 - val_accuracy: 0.7715 - val_loss: 0.4646 - val_pr_auc: 0.6162 - val_precision: 0.4584 - val_recall: 0.8030 - val_roc_auc: 0.8643 - learning_rate: 0.0010
# Epoch 24/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7759 - loss: 0.4700 - pr_auc: 0.8443 - precision: 0.7658 - recall: 0.7949 - roc_auc: 0.8565 - val_accuracy: 0.7801 - val_loss: 0.4479 - val_pr_auc: 0.6217 - val_precision: 0.4697 - val_recall: 0.7966 - val_roc_auc: 0.8672 - learning_rate: 0.0010
# Epoch 25/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7782 - loss: 0.4665 - pr_auc: 0.8475 - precision: 0.7684 - recall: 0.7964 - roc_auc: 0.8588 - val_accuracy: 0.7801 - val_loss: 0.4499 - val_pr_auc: 0.6219 - val_precision: 0.4698 - val_recall: 0.7955 - val_roc_auc: 0.8674 - learning_rate: 0.0010
# Epoch 26/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7799 - loss: 0.4644 - pr_auc: 0.8484 - precision: 0.7700 - recall: 0.7983 - roc_auc: 0.8603 - val_accuracy: 0.7783 - val_loss: 0.4529 - val_pr_auc: 0.6255 - val_precision: 0.4677 - val_recall: 0.8092 - val_roc_auc: 0.8687 - learning_rate: 0.0010
# Epoch 27/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7808 - loss: 0.4630 - pr_auc: 0.8495 - precision: 0.7703 - recall: 0.8000 - roc_auc: 0.8611 - val_accuracy: 0.7721 - val_loss: 0.4624 - val_pr_auc: 0.6258 - val_precision: 0.4599 - val_recall: 0.8180 - val_roc_auc: 0.8695 - learning_rate: 0.0010
# Epoch 28/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7809 - loss: 0.4609 - pr_auc: 0.8502 - precision: 0.7704 - recall: 0.8004 - roc_auc: 0.8623 - val_accuracy: 0.7805 - val_loss: 0.4502 - val_pr_auc: 0.6272 - val_precision: 0.4706 - val_recall: 0.8055 - val_roc_auc: 0.8705 - learning_rate: 0.0010
# Epoch 29/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7820 - loss: 0.4596 - pr_auc: 0.8521 - precision: 0.7713 - recall: 0.8016 - roc_auc: 0.8633 - val_accuracy: 0.7860 - val_loss: 0.4419 - val_pr_auc: 0.6312 - val_precision: 0.4781 - val_recall: 0.7990 - val_roc_auc: 0.8721 - learning_rate: 0.0010
# Epoch 30/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7828 - loss: 0.4579 - pr_auc: 0.8527 - precision: 0.7730 - recall: 0.8009 - roc_auc: 0.8644 - val_accuracy: 0.7783 - val_loss: 0.4508 - val_pr_auc: 0.6336 - val_precision: 0.4679 - val_recall: 0.8156 - val_roc_auc: 0.8728 - learning_rate: 0.0010
# Epoch 31/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7842 - loss: 0.4565 - pr_auc: 0.8534 - precision: 0.7729 - recall: 0.8048 - roc_auc: 0.8652 - val_accuracy: 0.7813 - val_loss: 0.4479 - val_pr_auc: 0.6325 - val_precision: 0.4719 - val_recall: 0.8131 - val_roc_auc: 0.8735 - learning_rate: 0.0010
# Epoch 32/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7837 - loss: 0.4549 - pr_auc: 0.8546 - precision: 0.7725 - recall: 0.8042 - roc_auc: 0.8663 - val_accuracy: 0.7819 - val_loss: 0.4468 - val_pr_auc: 0.6364 - val_precision: 0.4729 - val_recall: 0.8156 - val_roc_auc: 0.8752 - learning_rate: 0.0010
# Epoch 33/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7862 - loss: 0.4523 - pr_auc: 0.8572 - precision: 0.7760 - recall: 0.8047 - roc_auc: 0.8681 - val_accuracy: 0.7821 - val_loss: 0.4456 - val_pr_auc: 0.6371 - val_precision: 0.4732 - val_recall: 0.8181 - val_roc_auc: 0.8757 - learning_rate: 0.0010
# Epoch 34/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7862 - loss: 0.4530 - pr_auc: 0.8556 - precision: 0.7748 - recall: 0.8068 - roc_auc: 0.8675 - val_accuracy: 0.7806 - val_loss: 0.4478 - val_pr_auc: 0.6382 - val_precision: 0.4712 - val_recall: 0.8200 - val_roc_auc: 0.8761 - learning_rate: 0.0010
# Epoch 35/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7876 - loss: 0.4505 - pr_auc: 0.8579 - precision: 0.7772 - recall: 0.8064 - roc_auc: 0.8691 - val_accuracy: 0.7866 - val_loss: 0.4407 - val_pr_auc: 0.6413 - val_precision: 0.4792 - val_recall: 0.8097 - val_roc_auc: 0.8776 - learning_rate: 0.0010
# Epoch 36/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7901 - loss: 0.4485 - pr_auc: 0.8593 - precision: 0.7793 - recall: 0.8095 - roc_auc: 0.8704 - val_accuracy: 0.7874 - val_loss: 0.4363 - val_pr_auc: 0.6408 - val_precision: 0.4804 - val_recall: 0.8117 - val_roc_auc: 0.8783 - learning_rate: 0.0010
# Epoch 37/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7886 - loss: 0.4481 - pr_auc: 0.8597 - precision: 0.7776 - recall: 0.8085 - roc_auc: 0.8706 - val_accuracy: 0.7873 - val_loss: 0.4378 - val_pr_auc: 0.6410 - val_precision: 0.4803 - val_recall: 0.8134 - val_roc_auc: 0.8780 - learning_rate: 0.0010
# Epoch 38/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7910 - loss: 0.4458 - pr_auc: 0.8604 - precision: 0.7802 - recall: 0.8105 - roc_auc: 0.8721 - val_accuracy: 0.7879 - val_loss: 0.4360 - val_pr_auc: 0.6441 - val_precision: 0.4812 - val_recall: 0.8183 - val_roc_auc: 0.8801 - learning_rate: 0.0010
# Epoch 39/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7908 - loss: 0.4451 - pr_auc: 0.8617 - precision: 0.7792 - recall: 0.8117 - roc_auc: 0.8725 - val_accuracy: 0.7898 - val_loss: 0.4326 - val_pr_auc: 0.6457 - val_precision: 0.4840 - val_recall: 0.8149 - val_roc_auc: 0.8803 - learning_rate: 0.0010
# Epoch 40/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7924 - loss: 0.4438 - pr_auc: 0.8622 - precision: 0.7816 - recall: 0.8115 - roc_auc: 0.8735 - val_accuracy: 0.7937 - val_loss: 0.4281 - val_pr_auc: 0.6469 - val_precision: 0.4896 - val_recall: 0.8114 - val_roc_auc: 0.8813 - learning_rate: 0.0010
# Epoch 41/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7922 - loss: 0.4427 - pr_auc: 0.8621 - precision: 0.7813 - recall: 0.8116 - roc_auc: 0.8740 - val_accuracy: 0.7837 - val_loss: 0.4420 - val_pr_auc: 0.6454 - val_precision: 0.4758 - val_recall: 0.8312 - val_roc_auc: 0.8810 - learning_rate: 0.0010
# Epoch 42/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7956 - loss: 0.4393 - pr_auc: 0.8643 - precision: 0.7837 - recall: 0.8166 - roc_auc: 0.8763 - val_accuracy: 0.7872 - val_loss: 0.4386 - val_pr_auc: 0.6474 - val_precision: 0.4805 - val_recall: 0.8249 - val_roc_auc: 0.8815 - learning_rate: 0.0010
# Epoch 43/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7938 - loss: 0.4411 - pr_auc: 0.8635 - precision: 0.7826 - recall: 0.8137 - roc_auc: 0.8750 - val_accuracy: 0.7889 - val_loss: 0.4360 - val_pr_auc: 0.6485 - val_precision: 0.4828 - val_recall: 0.8238 - val_roc_auc: 0.8820 - learning_rate: 0.0010
# Epoch 44/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7933 - loss: 0.4411 - pr_auc: 0.8642 - precision: 0.7817 - recall: 0.8139 - roc_auc: 0.8750 - val_accuracy: 0.7885 - val_loss: 0.4370 - val_pr_auc: 0.6499 - val_precision: 0.4823 - val_recall: 0.8251 - val_roc_auc: 0.8829 - learning_rate: 0.0010
# Epoch 45/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7956 - loss: 0.4387 - pr_auc: 0.8660 - precision: 0.7841 - recall: 0.8158 - roc_auc: 0.8766 - val_accuracy: 0.7901 - val_loss: 0.4328 - val_pr_auc: 0.6480 - val_precision: 0.4845 - val_recall: 0.8232 - val_roc_auc: 0.8825 - learning_rate: 0.0010
# Epoch 46/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7929 - loss: 0.4388 - pr_auc: 0.8664 - precision: 0.7814 - recall: 0.8132 - roc_auc: 0.8764 - val_accuracy: 0.7937 - val_loss: 0.4273 - val_pr_auc: 0.6517 - val_precision: 0.4897 - val_recall: 0.8185 - val_roc_auc: 0.8839 - learning_rate: 0.0010
# Epoch 47/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7939 - loss: 0.4386 - pr_auc: 0.8670 - precision: 0.7826 - recall: 0.8140 - roc_auc: 0.8766 - val_accuracy: 0.7910 - val_loss: 0.4309 - val_pr_auc: 0.6519 - val_precision: 0.4858 - val_recall: 0.8249 - val_roc_auc: 0.8842 - learning_rate: 0.0010
# Epoch 48/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7973 - loss: 0.4355 - pr_auc: 0.8677 - precision: 0.7858 - recall: 0.8174 - roc_auc: 0.8784 - val_accuracy: 0.7961 - val_loss: 0.4226 - val_pr_auc: 0.6529 - val_precision: 0.4931 - val_recall: 0.8126 - val_roc_auc: 0.8845 - learning_rate: 0.0010
# Epoch 49/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7965 - loss: 0.4352 - pr_auc: 0.8676 - precision: 0.7847 - recall: 0.8171 - roc_auc: 0.8785 - val_accuracy: 0.7898 - val_loss: 0.4322 - val_pr_auc: 0.6525 - val_precision: 0.4842 - val_recall: 0.8256 - val_roc_auc: 0.8847 - learning_rate: 0.0010
# Epoch 50/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7991 - loss: 0.4341 - pr_auc: 0.8679 - precision: 0.7871 - recall: 0.8201 - roc_auc: 0.8794 - val_accuracy: 0.7927 - val_loss: 0.4298 - val_pr_auc: 0.6533 - val_precision: 0.4883 - val_recall: 0.8252 - val_roc_auc: 0.8854 - learning_rate: 0.0010
# Epoch 51/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7981 - loss: 0.4346 - pr_auc: 0.8679 - precision: 0.7860 - recall: 0.8192 - roc_auc: 0.8788 - val_accuracy: 0.7914 - val_loss: 0.4301 - val_pr_auc: 0.6533 - val_precision: 0.4864 - val_recall: 0.8262 - val_roc_auc: 0.8848 - learning_rate: 0.0010
# Epoch 52/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7990 - loss: 0.4332 - pr_auc: 0.8677 - precision: 0.7869 - recall: 0.8200 - roc_auc: 0.8797 - val_accuracy: 0.7885 - val_loss: 0.4355 - val_pr_auc: 0.6567 - val_precision: 0.4826 - val_recall: 0.8375 - val_roc_auc: 0.8861 - learning_rate: 0.0010
# Epoch 53/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8000 - loss: 0.4314 - pr_auc: 0.8701 - precision: 0.7883 - recall: 0.8204 - roc_auc: 0.8811 - val_accuracy: 0.7945 - val_loss: 0.4245 - val_pr_auc: 0.6575 - val_precision: 0.4909 - val_recall: 0.8237 - val_roc_auc: 0.8869 - learning_rate: 0.0010
# Epoch 54/100
# 123/123 - 1s - 5ms/step - accuracy: 0.7992 - loss: 0.4320 - pr_auc: 0.8692 - precision: 0.7873 - recall: 0.8201 - roc_auc: 0.8804 - val_accuracy: 0.7904 - val_loss: 0.4303 - val_pr_auc: 0.6574 - val_precision: 0.4851 - val_recall: 0.8324 - val_roc_auc: 0.8864 - learning_rate: 0.0010
# Epoch 55/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8000 - loss: 0.4310 - pr_auc: 0.8698 - precision: 0.7891 - recall: 0.8189 - roc_auc: 0.8811 - val_accuracy: 0.7990 - val_loss: 0.4157 - val_pr_auc: 0.6593 - val_precision: 0.4976 - val_recall: 0.8145 - val_roc_auc: 0.8874 - learning_rate: 0.0010
# Epoch 56/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8009 - loss: 0.4304 - pr_auc: 0.8705 - precision: 0.7887 - recall: 0.8220 - roc_auc: 0.8814 - val_accuracy: 0.7939 - val_loss: 0.4258 - val_pr_auc: 0.6591 - val_precision: 0.4900 - val_recall: 0.8272 - val_roc_auc: 0.8874 - learning_rate: 0.0010
# Epoch 57/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8012 - loss: 0.4288 - pr_auc: 0.8722 - precision: 0.7896 - recall: 0.8214 - roc_auc: 0.8826 - val_accuracy: 0.7922 - val_loss: 0.4299 - val_pr_auc: 0.6595 - val_precision: 0.4877 - val_recall: 0.8345 - val_roc_auc: 0.8881 - learning_rate: 0.0010
# Epoch 58/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8028 - loss: 0.4269 - pr_auc: 0.8726 - precision: 0.7904 - recall: 0.8241 - roc_auc: 0.8836 - val_accuracy: 0.7918 - val_loss: 0.4313 - val_pr_auc: 0.6576 - val_precision: 0.4872 - val_recall: 0.8356 - val_roc_auc: 0.8874 - learning_rate: 0.0010
# Epoch 59/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8014 - loss: 0.4278 - pr_auc: 0.8722 - precision: 0.7892 - recall: 0.8224 - roc_auc: 0.8830 - val_accuracy: 0.7904 - val_loss: 0.4316 - val_pr_auc: 0.6585 - val_precision: 0.4852 - val_recall: 0.8377 - val_roc_auc: 0.8879 - learning_rate: 0.0010
# Epoch 60/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8019 - loss: 0.4268 - pr_auc: 0.8723 - precision: 0.7892 - recall: 0.8240 - roc_auc: 0.8834 - val_accuracy: 0.7923 - val_loss: 0.4280 - val_pr_auc: 0.6587 - val_precision: 0.4879 - val_recall: 0.8351 - val_roc_auc: 0.8877 - learning_rate: 0.0010
# Epoch 61/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8027 - loss: 0.4268 - pr_auc: 0.8714 - precision: 0.7901 - recall: 0.8243 - roc_auc: 0.8835 - val_accuracy: 0.7946 - val_loss: 0.4246 - val_pr_auc: 0.6614 - val_precision: 0.4911 - val_recall: 0.8341 - val_roc_auc: 0.8893 - learning_rate: 0.0010
# Epoch 62/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8051 - loss: 0.4252 - pr_auc: 0.8733 - precision: 0.7925 - recall: 0.8267 - roc_auc: 0.8845 - val_accuracy: 0.7971 - val_loss: 0.4203 - val_pr_auc: 0.6632 - val_precision: 0.4948 - val_recall: 0.8304 - val_roc_auc: 0.8895 - learning_rate: 0.0010
# Epoch 63/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8043 - loss: 0.4246 - pr_auc: 0.8747 - precision: 0.7925 - recall: 0.8244 - roc_auc: 0.8851 - val_accuracy: 0.7948 - val_loss: 0.4265 - val_pr_auc: 0.6623 - val_precision: 0.4916 - val_recall: 0.8384 - val_roc_auc: 0.8899 - learning_rate: 0.0010
# Epoch 64/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8057 - loss: 0.4232 - pr_auc: 0.8749 - precision: 0.7936 - recall: 0.8264 - roc_auc: 0.8858 - val_accuracy: 0.7978 - val_loss: 0.4200 - val_pr_auc: 0.6634 - val_precision: 0.4959 - val_recall: 0.8325 - val_roc_auc: 0.8904 - learning_rate: 0.0010
# Epoch 65/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8042 - loss: 0.4220 - pr_auc: 0.8753 - precision: 0.7918 - recall: 0.8253 - roc_auc: 0.8862 - val_accuracy: 0.7942 - val_loss: 0.4255 - val_pr_auc: 0.6642 - val_precision: 0.4906 - val_recall: 0.8373 - val_roc_auc: 0.8904 - learning_rate: 0.0010
# Epoch 66/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8023 - loss: 0.4246 - pr_auc: 0.8742 - precision: 0.7898 - recall: 0.8239 - roc_auc: 0.8846 - val_accuracy: 0.7988 - val_loss: 0.4161 - val_pr_auc: 0.6673 - val_precision: 0.4974 - val_recall: 0.8316 - val_roc_auc: 0.8913 - learning_rate: 0.0010
# Epoch 67/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8058 - loss: 0.4221 - pr_auc: 0.8751 - precision: 0.7931 - recall: 0.8274 - roc_auc: 0.8863 - val_accuracy: 0.7960 - val_loss: 0.4228 - val_pr_auc: 0.6641 - val_precision: 0.4932 - val_recall: 0.8360 - val_roc_auc: 0.8904 - learning_rate: 0.0010
# Epoch 68/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8048 - loss: 0.4222 - pr_auc: 0.8767 - precision: 0.7928 - recall: 0.8255 - roc_auc: 0.8863 - val_accuracy: 0.7928 - val_loss: 0.4274 - val_pr_auc: 0.6671 - val_precision: 0.4887 - val_recall: 0.8444 - val_roc_auc: 0.8912 - learning_rate: 0.0010
# Epoch 69/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8055 - loss: 0.4223 - pr_auc: 0.8752 - precision: 0.7926 - recall: 0.8275 - roc_auc: 0.8863 - val_accuracy: 0.7972 - val_loss: 0.4211 - val_pr_auc: 0.6687 - val_precision: 0.4951 - val_recall: 0.8391 - val_roc_auc: 0.8922 - learning_rate: 0.0010
# Epoch 70/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8076 - loss: 0.4197 - pr_auc: 0.8768 - precision: 0.7955 - recall: 0.8280 - roc_auc: 0.8877 - val_accuracy: 0.8009 - val_loss: 0.4137 - val_pr_auc: 0.6684 - val_precision: 0.5005 - val_recall: 0.8293 - val_roc_auc: 0.8920 - learning_rate: 0.0010
# Epoch 71/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8071 - loss: 0.4194 - pr_auc: 0.8775 - precision: 0.7947 - recall: 0.8282 - roc_auc: 0.8880 - val_accuracy: 0.7995 - val_loss: 0.4152 - val_pr_auc: 0.6670 - val_precision: 0.4984 - val_recall: 0.8312 - val_roc_auc: 0.8918 - learning_rate: 0.0010
# Epoch 72/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8065 - loss: 0.4191 - pr_auc: 0.8779 - precision: 0.7941 - recall: 0.8275 - roc_auc: 0.8880 - val_accuracy: 0.7982 - val_loss: 0.4174 - val_pr_auc: 0.6702 - val_precision: 0.4965 - val_recall: 0.8382 - val_roc_auc: 0.8929 - learning_rate: 0.0010
# Epoch 73/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8079 - loss: 0.4189 - pr_auc: 0.8784 - precision: 0.7950 - recall: 0.8298 - roc_auc: 0.8882 - val_accuracy: 0.8008 - val_loss: 0.4142 - val_pr_auc: 0.6696 - val_precision: 0.5003 - val_recall: 0.8320 - val_roc_auc: 0.8925 - learning_rate: 0.0010
# Epoch 74/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8086 - loss: 0.4182 - pr_auc: 0.8781 - precision: 0.7959 - recall: 0.8302 - roc_auc: 0.8884 - val_accuracy: 0.7952 - val_loss: 0.4238 - val_pr_auc: 0.6700 - val_precision: 0.4921 - val_recall: 0.8421 - val_roc_auc: 0.8925 - learning_rate: 0.0010
# Epoch 75/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8084 - loss: 0.4156 - pr_auc: 0.8803 - precision: 0.7955 - recall: 0.8302 - roc_auc: 0.8900 - val_accuracy: 0.7981 - val_loss: 0.4209 - val_pr_auc: 0.6695 - val_precision: 0.4963 - val_recall: 0.8385 - val_roc_auc: 0.8930 - learning_rate: 0.0010
# Epoch 76/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8076 - loss: 0.4186 - pr_auc: 0.8781 - precision: 0.7951 - recall: 0.8286 - roc_auc: 0.8884 - val_accuracy: 0.7992 - val_loss: 0.4181 - val_pr_auc: 0.6661 - val_precision: 0.4979 - val_recall: 0.8332 - val_roc_auc: 0.8917 - learning_rate: 0.0010
# Epoch 77/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8107 - loss: 0.4129 - pr_auc: 0.8816 - precision: 0.7983 - recall: 0.8314 - roc_auc: 0.8915 - val_accuracy: 0.7975 - val_loss: 0.4195 - val_pr_auc: 0.6732 - val_precision: 0.4955 - val_recall: 0.8452 - val_roc_auc: 0.8949 - learning_rate: 5.0000e-04
# Epoch 78/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8111 - loss: 0.4109 - pr_auc: 0.8828 - precision: 0.7980 - recall: 0.8331 - roc_auc: 0.8927 - val_accuracy: 0.7981 - val_loss: 0.4174 - val_pr_auc: 0.6741 - val_precision: 0.4964 - val_recall: 0.8438 - val_roc_auc: 0.8953 - learning_rate: 5.0000e-04
# Epoch 79/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8127 - loss: 0.4084 - pr_auc: 0.8842 - precision: 0.8000 - recall: 0.8340 - roc_auc: 0.8939 - val_accuracy: 0.7991 - val_loss: 0.4173 - val_pr_auc: 0.6743 - val_precision: 0.4978 - val_recall: 0.8423 - val_roc_auc: 0.8953 - learning_rate: 5.0000e-04
# Epoch 80/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8133 - loss: 0.4066 - pr_auc: 0.8854 - precision: 0.8004 - recall: 0.8348 - roc_auc: 0.8950 - val_accuracy: 0.7985 - val_loss: 0.4180 - val_pr_auc: 0.6735 - val_precision: 0.4970 - val_recall: 0.8450 - val_roc_auc: 0.8957 - learning_rate: 5.0000e-04
# Epoch 81/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8137 - loss: 0.4082 - pr_auc: 0.8838 - precision: 0.8015 - recall: 0.8340 - roc_auc: 0.8942 - val_accuracy: 0.8010 - val_loss: 0.4148 - val_pr_auc: 0.6753 - val_precision: 0.5006 - val_recall: 0.8443 - val_roc_auc: 0.8963 - learning_rate: 5.0000e-04
# Epoch 82/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8141 - loss: 0.4071 - pr_auc: 0.8842 - precision: 0.8013 - recall: 0.8353 - roc_auc: 0.8948 - val_accuracy: 0.8013 - val_loss: 0.4159 - val_pr_auc: 0.6755 - val_precision: 0.5011 - val_recall: 0.8467 - val_roc_auc: 0.8962 - learning_rate: 5.0000e-04
# Epoch 83/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8131 - loss: 0.4087 - pr_auc: 0.8825 - precision: 0.8004 - recall: 0.8344 - roc_auc: 0.8938 - val_accuracy: 0.7992 - val_loss: 0.4164 - val_pr_auc: 0.6759 - val_precision: 0.4980 - val_recall: 0.8506 - val_roc_auc: 0.8967 - learning_rate: 5.0000e-04
# Epoch 84/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8146 - loss: 0.4066 - pr_auc: 0.8849 - precision: 0.8022 - recall: 0.8353 - roc_auc: 0.8951 - val_accuracy: 0.8009 - val_loss: 0.4162 - val_pr_auc: 0.6763 - val_precision: 0.5004 - val_recall: 0.8492 - val_roc_auc: 0.8970 - learning_rate: 5.0000e-04
# Epoch 85/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8135 - loss: 0.4080 - pr_auc: 0.8841 - precision: 0.8004 - recall: 0.8352 - roc_auc: 0.8943 - val_accuracy: 0.8020 - val_loss: 0.4116 - val_pr_auc: 0.6768 - val_precision: 0.5021 - val_recall: 0.8459 - val_roc_auc: 0.8973 - learning_rate: 5.0000e-04
# Epoch 86/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8163 - loss: 0.4050 - pr_auc: 0.8855 - precision: 0.8034 - recall: 0.8374 - roc_auc: 0.8959 - val_accuracy: 0.8015 - val_loss: 0.4161 - val_pr_auc: 0.6765 - val_precision: 0.5014 - val_recall: 0.8466 - val_roc_auc: 0.8969 - learning_rate: 5.0000e-04
# Epoch 87/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8152 - loss: 0.4065 - pr_auc: 0.8846 - precision: 0.8022 - recall: 0.8366 - roc_auc: 0.8950 - val_accuracy: 0.7993 - val_loss: 0.4182 - val_pr_auc: 0.6770 - val_precision: 0.4982 - val_recall: 0.8528 - val_roc_auc: 0.8973 - learning_rate: 5.0000e-04
# Epoch 88/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8146 - loss: 0.4052 - pr_auc: 0.8863 - precision: 0.8019 - recall: 0.8355 - roc_auc: 0.8959 - val_accuracy: 0.8017 - val_loss: 0.4145 - val_pr_auc: 0.6773 - val_precision: 0.5017 - val_recall: 0.8467 - val_roc_auc: 0.8974 - learning_rate: 5.0000e-04
# Epoch 89/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8154 - loss: 0.4050 - pr_auc: 0.8857 - precision: 0.8028 - recall: 0.8361 - roc_auc: 0.8961 - val_accuracy: 0.8006 - val_loss: 0.4156 - val_pr_auc: 0.6772 - val_precision: 0.5000 - val_recall: 0.8494 - val_roc_auc: 0.8974 - learning_rate: 5.0000e-04
# Epoch 90/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8156 - loss: 0.4054 - pr_auc: 0.8859 - precision: 0.8032 - recall: 0.8360 - roc_auc: 0.8958 - val_accuracy: 0.8016 - val_loss: 0.4143 - val_pr_auc: 0.6780 - val_precision: 0.5014 - val_recall: 0.8476 - val_roc_auc: 0.8978 - learning_rate: 5.0000e-04
# Epoch 91/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8165 - loss: 0.4029 - pr_auc: 0.8873 - precision: 0.8036 - recall: 0.8377 - roc_auc: 0.8972 - val_accuracy: 0.8008 - val_loss: 0.4144 - val_pr_auc: 0.6774 - val_precision: 0.5004 - val_recall: 0.8487 - val_roc_auc: 0.8977 - learning_rate: 5.0000e-04
# Epoch 92/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8160 - loss: 0.4046 - pr_auc: 0.8859 - precision: 0.8026 - recall: 0.8380 - roc_auc: 0.8962 - val_accuracy: 0.8002 - val_loss: 0.4160 - val_pr_auc: 0.6784 - val_precision: 0.4994 - val_recall: 0.8488 - val_roc_auc: 0.8975 - learning_rate: 5.0000e-04
# Epoch 93/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8155 - loss: 0.4036 - pr_auc: 0.8863 - precision: 0.8030 - recall: 0.8361 - roc_auc: 0.8966 - val_accuracy: 0.8013 - val_loss: 0.4157 - val_pr_auc: 0.6766 - val_precision: 0.5011 - val_recall: 0.8493 - val_roc_auc: 0.8974 - learning_rate: 5.0000e-04
# Epoch 94/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8163 - loss: 0.4035 - pr_auc: 0.8870 - precision: 0.8032 - recall: 0.8381 - roc_auc: 0.8969 - val_accuracy: 0.8020 - val_loss: 0.4147 - val_pr_auc: 0.6782 - val_precision: 0.5021 - val_recall: 0.8505 - val_roc_auc: 0.8977 - learning_rate: 5.0000e-04
# Epoch 95/100
# 123/123 - 1s - 6ms/step - accuracy: 0.8157 - loss: 0.4039 - pr_auc: 0.8862 - precision: 0.8023 - recall: 0.8380 - roc_auc: 0.8964 - val_accuracy: 0.8008 - val_loss: 0.4148 - val_pr_auc: 0.6777 - val_precision: 0.5004 - val_recall: 0.8492 - val_roc_auc: 0.8977 - learning_rate: 5.0000e-04
# Epoch 96/100
# 123/123 - 1s - 6ms/step - accuracy: 0.8163 - loss: 0.4036 - pr_auc: 0.8861 - precision: 0.8037 - recall: 0.8370 - roc_auc: 0.8966 - val_accuracy: 0.8031 - val_loss: 0.4124 - val_pr_auc: 0.6784 - val_precision: 0.5038 - val_recall: 0.8474 - val_roc_auc: 0.8983 - learning_rate: 5.0000e-04
# Epoch 97/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8184 - loss: 0.4005 - pr_auc: 0.8887 - precision: 0.8056 - recall: 0.8394 - roc_auc: 0.8984 - val_accuracy: 0.8010 - val_loss: 0.4153 - val_pr_auc: 0.6800 - val_precision: 0.5007 - val_recall: 0.8519 - val_roc_auc: 0.8988 - learning_rate: 2.5000e-04
# Epoch 98/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8183 - loss: 0.3996 - pr_auc: 0.8887 - precision: 0.8049 - recall: 0.8402 - roc_auc: 0.8989 - val_accuracy: 0.7999 - val_loss: 0.4169 - val_pr_auc: 0.6807 - val_precision: 0.4990 - val_recall: 0.8531 - val_roc_auc: 0.8987 - learning_rate: 2.5000e-04
# Epoch 99/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8191 - loss: 0.3997 - pr_auc: 0.8887 - precision: 0.8062 - recall: 0.8401 - roc_auc: 0.8990 - val_accuracy: 0.8019 - val_loss: 0.4128 - val_pr_auc: 0.6809 - val_precision: 0.5020 - val_recall: 0.8520 - val_roc_auc: 0.8993 - learning_rate: 2.5000e-04
# Epoch 100/100
# 123/123 - 1s - 5ms/step - accuracy: 0.8198 - loss: 0.3969 - pr_auc: 0.8906 - precision: 0.8069 - recall: 0.8407 - roc_auc: 0.9002 - val_accuracy: 0.8022 - val_loss: 0.4140 - val_pr_auc: 0.6809 - val_precision: 0.5024 - val_recall: 0.8531 - val_roc_auc: 0.8993 - learning_rate: 2.5000e-04
# Accident classifier training complete.
# Features: 102
# Train rows: 125,826
# Validation rows: 67,599
# Test rows: 67,600
# Model: artifacts/models/mlp_accident_classifier_random_under_sampling_two_stage.keras
# Metrics: artifacts/reports/mlp_accident_classifier_random_under_sampling_two_stage_metrics.json
# History: artifacts/reports/mlp_accident_classifier_random_under_sampling_two_stage_history.csv
# Predictions: artifacts/predictions/mlp_accident_classifier_random_under_sampling_two_stage_test_predictions.csv
# Threshold metrics:
# {
#   "threshold": 0.5,
#   "accuracy": 0.8063609467455621,
#   "precision": 0.5086610693769332,
#   "recall": 0.8538050734312417,
#   "f1": 0.6375166149756313,
#   "true_positive": 11511,
#   "false_positive": 11119,
#   "true_negative": 42999,
#   "false_negative": 1971
# }
# Top-K metrics:
# {
#   "1000": {
#     "k": 1000,
#     "hit_count": 883,
#     "precision_at_k": 0.883,
#     "recall_at_k": 0.06549473371903279,
#     "f1_at_k": 0.12194448280624223
#   }
# }

# %%
model2_command = [
    sys.executable,
    str(PROJECT_ROOT / 'scripts' / 'train' / 'train_positive_risk_regressor.py'),
    '--train', str(TRAIN_PATH),
    '--val', str(VAL_PATH),
    '--test', str(TEST_PATH),
    '--model-path', str(MODEL2_MODEL_PATH),
    '--metrics-path', str(MODEL2_METRICS_PATH),
    '--history-path', str(MODEL2_HISTORY_PATH),
    '--predictions-path', str(MODEL2_PREDICTIONS_PATH),
    '--epochs', '100',
    '--batch-size', '1024',
    '--device', 'auto',
    '--verbose', '2',
]

print('모델 2 학습 명령:')
print(' '.join(model2_command))
print('주의: 모델 2 학습 스크립트는 내부에서 위험도 > 0 데이터만 필터링합니다.')

if RUN_TRAINING:
    subprocess.run(model2_command, check=True)
else:
    print('RUN_TRAINING=False 상태입니다. 실제 모델 2 학습은 실행하지 않았습니다.')
# Out:
# 모델 2 학습 명령:
# /home/huichan/SPARV/SilverWalk/.venv/bin/python /home/huichan/SPARV/SilverWalk/scripts/train/train_positive_risk_regressor.py --train /home/huichan/SPARV/SilverWalk/data/processed/original_train_train_preprocessed.csv --val /home/huichan/SPARV/SilverWalk/data/processed/original_train_val_preprocessed.csv --test /home/huichan/SPARV/SilverWalk/data/processed/original_train_test_preprocessed.csv --model-path /home/huichan/SPARV/SilverWalk/artifacts/models/mlp_positive_risk_regressor_random_under_sampling_two_stage.keras --metrics-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_positive_risk_regressor_random_under_sampling_two_stage_metrics.json --history-path /home/huichan/SPARV/SilverWalk/artifacts/reports/mlp_positive_risk_regressor_random_under_sampling_two_stage_history.csv --predictions-path /home/huichan/SPARV/SilverWalk/artifacts/predictions/mlp_positive_risk_regressor_random_under_sampling_two_stage_test_predictions.csv --epochs 100 --batch-size 1024 --device auto --verbose 2
# 주의: 모델 2 학습 스크립트는 내부에서 위험도 > 0 데이터만 필터링합니다.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780780916.574138   18701 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780780916.601670   18701 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780780917.419450   18701 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# W0000 00:00:1780780918.141632   18701 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/100
# 62/62 - 1s - 18ms/step - loss: 0.4013 - mae: 0.7566 - rmse: 1.0118 - val_loss: 0.3432 - val_mae: 0.6737 - val_rmse: 0.9572 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 - 0s - 5ms/step - loss: 0.3063 - mae: 0.6395 - rmse: 0.8633 - val_loss: 0.2940 - val_mae: 0.6190 - val_rmse: 0.8674 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 - 0s - 5ms/step - loss: 0.2900 - mae: 0.6174 - rmse: 0.8379 - val_loss: 0.2726 - val_mae: 0.5923 - val_rmse: 0.8237 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 - 0s - 5ms/step - loss: 0.2803 - mae: 0.6046 - rmse: 0.8212 - val_loss: 0.2611 - val_mae: 0.5776 - val_rmse: 0.7987 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 - 0s - 5ms/step - loss: 0.2732 - mae: 0.5949 - rmse: 0.8084 - val_loss: 0.2538 - val_mae: 0.5679 - val_rmse: 0.7832 - learning_rate: 0.0010
# Epoch 6/100
# 62/62
# 62/62 - 0s - 5ms/step - loss: 0.1549 - mae: 0.4327 - rmse: 0.5798 - val_loss: 0.1464 - val_mae: 0.4116 - val_rmse: 0.5682 - learning_rate: 0.0010
# Epoch 78/100
# 62/62 - 0s - 5ms/step - loss: 0.1553 - mae: 0.4329 - rmse: 0.5805 - val_loss: 0.1475 - val_mae: 0.4143 - val_rmse: 0.5705 - learning_rate: 0.0010
# Epoch 79/100
# 62/62 - 0s - 5ms/step - loss: 0.1552 - mae: 0.4330 - rmse: 0.5802 - val_loss: 0.1484 - val_mae: 0.4143 - val_rmse: 0.5728 - learning_rate: 0.0010
# Epoch 80/100
# 62/62 - 0s - 4ms/step - loss: 0.1530 - mae: 0.4294 - rmse: 0.5755 - val_loss: 0.1478 - val_mae: 0.4124 - val_rmse: 0.5717 - learning_rate: 0.0010
# Epoch 81/100
# 62/62 - 0s - 5ms/step - loss: 0.1516 - mae: 0.4282 - rmse: 0.5724 - val_loss: 0.1444 - val_mae: 0.4076 - val_rmse: 0.5643 - learning_rate: 5.0000e-04
# Epoch 82/100
# 62/62 - 0s - 5ms/step - loss: 0.1495 - mae: 0.4253 - rmse: 0.5682 - val_loss: 0.1430 - val_mae: 0.4046 - val_rmse: 0.5618 - learning_rate: 5.0000e-04
# Epoch 83/100
# 62/62 - 0s - 5ms/step - loss: 0.1491 - mae: 0.4239 - rmse: 0.5679 - val_loss: 0.1426 - val_mae: 0.4041 - val_rmse: 0.5613 - learning_rate: 5.0000e-04
# Epoch 84/100
# 62/62 - 0s - 5ms/step - loss: 0.1486 - mae: 0.4229 - rmse: 0.5668 - val_loss: 0.1411 - val_mae: 0.4017 - val_rmse: 0.5577 - learning_rate: 5.0000e-04
# Epoch 85/100
# 62/62 - 0s - 4ms/step - loss: 0.1481 - mae: 0.4219 - rmse: 0.5651 - val_loss: 0.1425 - val_mae: 0.4038 - val_rmse: 0.5608 - learning_rate: 5.0000e-04
# Epoch 86/100
# 62/62 - 0s - 4ms/step - loss: 0.1482 - mae: 0.4226 - rmse: 0.5653 - val_loss: 0.1418 - val_mae: 0.4029 - val_rmse: 0.5595 - learning_rate: 5.0000e-04
# Epoch 87/100
# 62/62 - 0s - 5ms/step - loss: 0.1484 - mae: 0.4230 - rmse: 0.5656 - val_loss: 0.1421 - val_mae: 0.4032 - val_rmse: 0.5600 - learning_rate: 5.0000e-04
# Epoch 88/100
# 62/62 - 0s - 5ms/step - loss: 0.1471 - mae: 0.4210 - rmse: 0.5631 - val_loss: 0.1414 - val_mae: 0.4016 - val_rmse: 0.5587 - learning_rate: 5.0000e-04
# Epoch 89/100
# 62/62 - 0s - 5ms/step - loss: 0.1459 - mae: 0.4189 - rmse: 0.5608 - val_loss: 0.1399 - val_mae: 0.3996 - val_rmse: 0.5554 - learning_rate: 2.5000e-04
# Epoch 90/100
# 62/62 - 0s - 5ms/step - loss: 0.1455 - mae: 0.4187 - rmse: 0.5595 - val_loss: 0.1397 - val_mae: 0.3994 - val_rmse: 0.5551 - learning_rate: 2.5000e-04
# Epoch 91/100
# 62/62 - 0s - 4ms/step - loss: 0.1459 - mae: 0.4185 - rmse: 0.5604 - val_loss: 0.1405 - val_mae: 0.4003 - val_rmse: 0.5566 - learning_rate: 2.5000e-04
# Epoch 92/100
# 62/62 - 0s - 4ms/step - loss: 0.1455 - mae: 0.4179 - rmse: 0.5599 - val_loss: 0.1401 - val_mae: 0.3999 - val_rmse: 0.5559 - learning_rate: 2.5000e-04
# Epoch 93/100
# 62/62 - 0s - 5ms/step - loss: 0.1457 - mae: 0.4188 - rmse: 0.5604 - val_loss: 0.1395 - val_mae: 0.3987 - val_rmse: 0.5547 - learning_rate: 2.5000e-04
# Epoch 94/100
# 62/62 - 0s - 5ms/step - loss: 0.1458 - mae: 0.4186 - rmse: 0.5606 - val_loss: 0.1389 - val_mae: 0.3980 - val_rmse: 0.5532 - learning_rate: 2.5000e-04
# Epoch 95/100
# 62/62 - 0s - 5ms/step - loss: 0.1440 - mae: 0.4163 - rmse: 0.5568 - val_loss: 0.1392 - val_mae: 0.3981 - val_rmse: 0.5541 - learning_rate: 2.5000e-04
# Epoch 96/100
# 62/62 - 0s - 5ms/step - loss: 0.1448 - mae: 0.4168 - rmse: 0.5585 - val_loss: 0.1384 - val_mae: 0.3965 - val_rmse: 0.5521 - learning_rate: 2.5000e-04
# Epoch 97/100
# 62/62 - 0s - 5ms/step - loss: 0.1451 - mae: 0.4176 - rmse: 0.5593 - val_loss: 0.1385 - val_mae: 0.3969 - val_rmse: 0.5525 - learning_rate: 2.5000e-04
# Epoch 98/100
# 62/62 - 0s - 4ms/step - loss: 0.1444 - mae: 0.4157 - rmse: 0.5572 - val_loss: 0.1392 - val_mae: 0.3982 - val_rmse: 0.5539 - learning_rate: 2.5000e-04
# Epoch 99/100
# 62/62 - 0s - 5ms/step - loss: 0.1444 - mae: 0.4165 - rmse: 0.5575 - val_loss: 0.1394 - val_mae: 0.3980 - val_rmse: 0.5545 - learning_rate: 2.5000e-04
# Epoch 100/100
# 62/62 - 0s - 4ms/step - loss: 0.1437 - mae: 0.4153 - rmse: 0.5562 - val_loss: 0.1399 - val_mae: 0.3984 - val_rmse: 0.5556 - learning_rate: 2.5000e-04
# Positive risk regressor training complete.
# Features: 102
# Raw train rows: 315,464 -> positive: 62,913
# Raw validation rows: 67,599 -> positive: 13,481
# Raw test rows: 67,600 -> positive: 13,482
# Model: artifacts/models/mlp_positive_risk_regressor_random_under_sampling_two_stage.keras
# Metrics: artifacts/reports/mlp_positive_risk_regressor_random_under_sampling_two_stage_metrics.json
# History: artifacts/reports/mlp_positive_risk_regressor_random_under_sampling_two_stage_history.csv
# Predictions: artifacts/predictions/mlp_positive_risk_regressor_random_under_sampling_two_stage_test_predictions.csv
# Test risk-scale metrics:
# {
#   "mae": 2.010984105092137,
#   "rmse": 6.255205888040459,
#   "r2": 0.5404532370983584
# }

# %% [markdown]
# ## 결과 지표 표 위치
#
# 실험을 실행한 뒤 아래 지표만 `docs/기법별_성능평가.md`의 평가표에 작성한다.
#
# | 모델 | PR-AUC | Recall@Top10% | Precision@Top10% | MAE | RMSE |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | 실험명 | 실행 후 입력 | 실행 후 입력 | 실행 후 입력 | 실행 후 입력 | 실행 후 입력 |

# %%
def top_percent_binary_metrics(predictions: pd.DataFrame, score_column: str, target_column: str, percent: float = 0.10) -> dict[str, float]:
    """예측 점수 상위 percent 구간의 precision/recall을 계산한다."""
    if predictions.empty:
        return {'precision_top10pct': math.nan, 'recall_top10pct': math.nan}

    k = max(1, math.ceil(len(predictions) * percent))
    ranked = predictions.sort_values(score_column, ascending=False).head(k)
    actual_positive = predictions[target_column].astype(int)
    top_positive = ranked[target_column].astype(int)

    precision = float(top_positive.sum() / k)
    recall = float(top_positive.sum() / actual_positive.sum()) if actual_positive.sum() else math.nan
    return {'precision_top10pct': precision, 'recall_top10pct': recall}


def rmse(y_true: pd.Series, y_pred: pd.Series) -> float:
    """scikit-learn 버전 차이를 피하기 위해 RMSE를 직접 계산한다."""
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))


if MODEL1_PREDICTIONS_PATH.exists() and MODEL2_PREDICTIONS_PATH.exists():
    model1_predictions = pd.read_csv(MODEL1_PREDICTIONS_PATH)
    model2_predictions = pd.read_csv(MODEL2_PREDICTIONS_PATH)

    model1_summary = top_percent_binary_metrics(
        model1_predictions,
        score_column='사고발생확률',
        target_column='사고발생',
        percent=0.10,
    )
    model1_summary['pr_auc'] = float(
        average_precision_score(model1_predictions['사고발생'], model1_predictions['사고발생확률'])
    )

    model2_summary = {
        'mae': float(mean_absolute_error(model2_predictions['위험도'], model2_predictions['pred_위험도'])),
        'rmse': rmse(model2_predictions['위험도'], model2_predictions['pred_위험도']),
    }

    summary = pd.DataFrame([
        {
            '모델': EXPERIMENT_NAME,
            'PR-AUC': model1_summary['pr_auc'],
            'Recall@Top10%': model1_summary['recall_top10pct'],
            'Precision@Top10%': model1_summary['precision_top10pct'],
            'MAE': model2_summary['mae'],
            'RMSE': model2_summary['rmse'],
        }
    ])

    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    summary.to_csv(EXPERIMENT_RESULT_PATH, index=False)
    display(summary)
    print(f'실험 요약 저장: {EXPERIMENT_RESULT_PATH.relative_to(PROJECT_ROOT)}')
    print(f'문서 평가표 위치: {DOCS_TABLE_PATH.relative_to(PROJECT_ROOT)}')
else:
    print('아직 모델 예측 파일이 없습니다. RUN_SAMPLING=True, RUN_TRAINING=True로 학습을 마친 뒤 다시 실행하십시오.')
    print(f'필요 파일: {MODEL1_PREDICTIONS_PATH.relative_to(PROJECT_ROOT)}')
    print(f'필요 파일: {MODEL2_PREDICTIONS_PATH.relative_to(PROJECT_ROOT)}')
# Out:
#                                                   모델    PR-AUC  Recall@Top10%  \
# 0  Undersampling Random under Sampling (비율 1대1) +...  0.681522        0.37665
#
#    Precision@Top10%       MAE      RMSE
# 0          0.751183  2.010984  6.255206
# 실험 요약 저장: artifacts/experiments/random_under_sampling_two_stage/random_under_sampling_two_stage_summary.csv
# 문서 평가표 위치: docs/기법별_성능평가.md
